# %% [markdown]
# # Background information on repos
#
# Supports Python 3.6+

# %%
import csv
import json
import os
import pprint

import requests

# %%
# get api token and set authorization
api_token = os.environ['GITHUB_API_TOKEN']
headers = {'Authorization': f'token {api_token}'}

# %%
# set url to a graphql endpoint
url = 'https://api.github.com/graphql'

# %%
# add a json query
query = """
{
  organization(login: "nteract") {
    name
    repositories(first: 80) {
      nodes {
        name
        url
        description
        id
        pushedAt
        createdAt
      }
    }
  }
}
"""

# %%
# submit the request
r = requests.post(url=url, json={'query': query}, headers=headers)

# %%
result = r.json()
#result

# %%
import pandas as pd

# %%
repos = pd.DataFrame(result['data']['organization']['repositories']['nodes'], columns=['name', 'url', 'description', 'pushedAt', 'createdAt'])
#repos

# %% [markdown]
# ### Reports

# %%
# By repo name
sorted_df = repos.sort_values(by=['name'])
sorted_df
# Out:
#                                  name  \
# 31                      ansi-to-react
# 34                             assets
# 35                         associator
# 58                            cabinet
# 14                         commutable
# 54                  commutable-models
# 49                    commutable-perf
# 52                           commuter
# 23                             design
# 56                     desktop-manual
# 27                               docs
# 17                          enchannel
# 29                enchannel-in-memory
# 30         enchannel-notebook-backend
# 26         enchannel-socketio-backend
# 16              enchannel-zmq-backend
# 1                            hydrogen
# 19                                ick
# 38                        initiatives
# 45                            inodejs
# 12                      ipython-paths
# 5                jupyter-display-area
# 10            jupyter-kernel-launcher
# 2                       jupyter-paths
# 9                     jupyter-session
# 11          jupyter-transport-wrapper
# 25                       kernel-relay
# 21                        kernelspecs
# 48                         libzmq-win
# 28                              logos
# ..                                ...
# 40                    meeting-minutes
# 55                     minimal-plotly
# 37                             naming
# 36                   notebook-preview
# 18                 notebook-test-data
# 3                             nteract
# 4                   nteract.github.io
# 43                         nteract.io
# 42                       oauth-server
# 57                          papermill
# 59                         papermillr
# 50                          plotly.js
# 15         react-jupyter-display-area
# 47                         rx-jupyter
# 0                             sidecar
# 53                       snakestagram
# 22                        spawnteract
# 24                              specs
# 39                      term-launcher
# 20                   terminal-sidecar
# 46                          tick-tock
# 6                        transformime
# 8             transformime-commonmark
# 7   transformime-jupyter-transformers
# 32                transformime-marked
# 13                 transformime-react
# 60                               vdom
# 51                               vega
# 41               zmq-prebuilt-testing
# 44                         zmq-static
#
#                                                   url  \
# 31           https://github.com/nteract/ansi-to-react
# 34                  https://github.com/nteract/assets
# 35              https://github.com/nteract/associator
# 58                 https://github.com/nteract/cabinet
# 14              https://github.com/nteract/commutable
# 54       https://github.com/nteract/commutable-models
# 49         https://github.com/nteract/commutable-perf
# 52                https://github.com/nteract/commuter
# 23                  https://github.com/nteract/design
# 56          https://github.com/nteract/desktop-manual
# 27                    https://github.com/nteract/docs
# 17               https://github.com/nteract/enchannel
# 29     https://github.com/nteract/enchannel-in-memory
# 30  https://github.com/nteract/enchannel-notebook-...
# 26  https://github.com/nteract/enchannel-socketio-...
# 16   https://github.com/nteract/enchannel-zmq-backend
# 1                 https://github.com/nteract/hydrogen
# 19                     https://github.com/nteract/ick
# 38             https://github.com/nteract/initiatives
# 45                 https://github.com/nteract/inodejs
# 12           https://github.com/nteract/ipython-paths
# 5     https://github.com/nteract/jupyter-display-area
# 10  https://github.com/nteract/jupyter-kernel-laun...
# 2            https://github.com/nteract/jupyter-paths
# 9          https://github.com/nteract/jupyter-session
# 11  https://github.com/nteract/jupyter-transport-w...
# 25            https://github.com/nteract/kernel-relay
# 21             https://github.com/nteract/kernelspecs
# 48              https://github.com/nteract/libzmq-win
# 28                   https://github.com/nteract/logos
# ..                                                ...
# 40         https://github.com/nteract/meeting-minutes
# 55          https://github.com/nteract/minimal-plotly
# 37                  https://github.com/nteract/naming
# 36        https://github.com/nteract/notebook-preview
# 18      https://github.com/nteract/notebook-test-data
# 3                  https://github.com/nteract/nteract
# 4        https://github.com/nteract/nteract.github.io
# 43              https://github.com/nteract/nteract.io
# 42            https://github.com/nteract/oauth-server
# 57               https://github.com/nteract/papermill
# 59              https://github.com/nteract/papermillr
# 50               https://github.com/nteract/plotly.js
# 15  https://github.com/nteract/react-jupyter-displ...
# 47              https://github.com/nteract/rx-jupyter
# 0                  https://github.com/nteract/sidecar
# 53            https://github.com/nteract/snakestagram
# 22             https://github.com/nteract/spawnteract
# 24                   https://github.com/nteract/specs
# 39           https://github.com/nteract/term-launcher
# 20        https://github.com/nteract/terminal-sidecar
# 46               https://github.com/nteract/tick-tock
# 6             https://github.com/nteract/transformime
# 8   https://github.com/nteract/transformime-common...
# 7   https://github.com/nteract/transformime-jupyte...
# 32     https://github.com/nteract/transformime-marked
# 13      https://github.com/nteract/transformime-react
# 60                    https://github.com/nteract/vdom
# 51                    https://github.com/nteract/vega
# 41    https://github.com/nteract/zmq-prebuilt-testing
# 44              https://github.com/nteract/zmq-static
#
#                                           description              pushedAt  \
# 31                          :guardsman: ANSI to React  2017-08-15T18:20:33Z
# 34        :package: static assets for nteract/nteract  2017-11-17T00:56:18Z
# 35  :busts_in_silhouette: Associates file extensio...  2017-01-20T21:48:51Z
# 58        📕 Exploring a new notebook container format  2017-11-01T20:46:05Z
# 14  :recycle: Operations for Immutable Notebook Do...  2017-05-08T22:50:42Z
# 54  :recycle: 📘 Experimenting with commutable and ...  2017-01-20T21:49:01Z
# 49  🐢 Addressing performance of the commutable lib...  2016-11-09T19:12:35Z
# 52           🚎 share, publish, and discover notebooks  2017-11-24T18:30:57Z
# 23             :pencil2: Mocking up nteract UI and UX  2017-07-18T20:15:31Z
# 56                 The field guide to nteract desktop  2017-06-03T00:54:24Z
# 27  :notebook_with_decorative_cover: docs are awesome  2017-06-20T18:19:30Z
# 17  :currency_exchange: standardizing how a fronte...  2017-08-13T20:33:10Z
# 29             :computer: In memory enchannel backend  2017-01-20T21:49:23Z
# 30  :notebook: Enchannel backend for connecting to...  2017-01-20T21:49:29Z
# 26  :electric_plug: enchannel powered by socket.io...  2017-01-20T21:49:34Z
# 16  :currency_exchange: Channeling Jupyter over zm...  2017-08-17T16:08:44Z
# 1   :atom: Run code interactively, inspect data, a...  2017-12-13T15:56:37Z
# 19  :izakaya_lantern: Interactive Console Experiments  2017-01-20T22:13:54Z
# 38  :bookmark_tabs: Top level initiatives that our...  2017-03-17T14:34:10Z
# 45                       Experimenting with jp-kernel  2017-04-01T00:21:29Z
# 12  :city_sunset: Paths for IPython before Jupyter...  2017-01-20T22:17:33Z
# 5   :no_entry_sign: Prototype Web Component for Ju...  2017-01-20T21:50:00Z
# 10   Launches Jupyter kernels from a Node environment  2017-01-20T21:50:06Z
# 2   :city_sunrise: Pure JavaScript implementation ...  2017-07-19T16:46:33Z
# 9         A tool for interacting with Jupyter kernels  2017-01-20T21:50:17Z
# 11  A thin wrapper abstracting over ZMQ and (evenu...  2017-01-20T21:50:22Z
# 25    :runner: socketio-zmq relay for Jupyter kernels  2017-01-20T21:50:27Z
# 21  :card_index: Find Jupyter kernelspecs on a system  2017-08-10T17:38:38Z
# 48      :package: Windows binaries of the ØMQ library  2017-06-01T15:16:04Z
# 28  :sparkles: A place to collaborate on nteract l...  2017-07-06T21:24:37Z
# ..                                                ...                   ...
# 40  :memo: Minutes from the nteract developer meet...  2017-05-22T21:39:52Z
# 55  :bar_chart: A minimal version of the plotly li...  2017-04-11T21:33:12Z
# 37          :name_badge: Shipping releases with style  2016-09-12T23:12:51Z
# 36  :movie_camera: Lightweight preview of a notebo...  2017-02-13T18:44:11Z
# 18  :books: Jupyter notebook test data. Feel free ...  2017-01-21T15:41:21Z
# 3                   📘 Desktop notebook app + packages  2017-12-13T22:00:31Z
# 4                  :octocat: GitHub Pages for nteract  2017-04-29T01:16:19Z
# 43                            :mega: Our site! :mega:  2017-10-29T20:31:38Z
# 42         🔏 Little OAuth Handler for Gist Publishing  2017-04-28T17:15:10Z
# 57     📚 Parameterize, execute, and analyze notebooks  2017-12-08T05:50:00Z
# 59                           R bindings for papermill  2017-08-01T21:41:01Z
# 50  The open source JavaScript graphing library th...  2016-12-26T02:41:00Z
# 15  :bar_chart: Jupyter Display Area as a React Co...  2017-05-09T20:48:44Z
# 47     🎈 RxJS 5 bindings for the Jupyter Notebook API  2017-10-29T20:07:22Z
# 0   :speedboat: Little side display of Jupyter ker...  2017-07-19T16:46:35Z
# 53  :snake: :package: Snake in a box, conda enviro...  2017-02-10T15:53:25Z
# 22          :children_crossing: Spawn Jupyter Kernels  2017-08-10T18:35:55Z
# 24  :bookmark_tabs: Specifications for APIs, proce...  2016-06-14T22:59:50Z
# 39  :computer: :rocket: Launch terminals and jupyt...  2017-08-05T09:27:15Z
# 20      :speedboat: Jupyter Sidecar, in the terminal!  2017-01-20T21:51:56Z
# 46           :clock4: Exploring Clock Synchronization  2016-10-08T03:20:36Z
# 6              :truck: Mimetype + data -> HTMLElement  2017-08-22T00:25:06Z
# 8     :no_entry_sign: Transformer using commonmark.js  2017-01-20T21:52:08Z
# 7   :no_entry_sign: Transformers for Jupyter-speci...  2017-01-20T21:52:14Z
# 32                 :cyclone: Transformer using marked  2017-01-20T21:52:19Z
# 13                 🚫 Mimetype + data -> React Element  2017-05-08T22:49:40Z
# 60                                  🎄 VDOM for Python  2017-11-21T17:40:54Z
# 17                          enchannel
# 18                 notebook-test-data
# 19                                ick
# 20                   terminal-sidecar
# 21                        kernelspecs
# 22                        spawnteract
# 23                             design
# 24                              specs
# 25                       kernel-relay
# 26         enchannel-socketio-backend
# 27                               docs
# 28                              logos
# 29                enchannel-in-memory
# ..                                ...
# 31                      ansi-to-react
# 32                transformime-marked
# 33                   mathjax-electron
# 34                             assets
# 35                         associator
# 36                   notebook-preview
# 37                             naming
# 38                        initiatives
# 39                      term-launcher
# 40                    meeting-minutes
# 41               zmq-prebuilt-testing
# 42                       oauth-server
# 43                         nteract.io
# 44                         zmq-static
# 45                            inodejs
# 46                          tick-tock
# 47                         rx-jupyter
# 48                         libzmq-win
# 49                    commutable-perf
# 50                          plotly.js
# 51                               vega
# 52                           commuter
# 53                       snakestagram
# 54                  commutable-models
# 55                     minimal-plotly
# 56                     desktop-manual
# 57                          papermill
# 58                            cabinet
# 59                         papermillr
# 60                               vdom
#
#                                                   url  \
# 0                  https://github.com/nteract/sidecar
# 1                 https://github.com/nteract/hydrogen
# 2            https://github.com/nteract/jupyter-paths
# 3                  https://github.com/nteract/nteract
# 4        https://github.com/nteract/nteract.github.io
# 5     https://github.com/nteract/jupyter-display-area
# 6             https://github.com/nteract/transformime
# 7   https://github.com/nteract/transformime-jupyte...
# 8   https://github.com/nteract/transformime-common...
# 9          https://github.com/nteract/jupyter-session
# 10  https://github.com/nteract/jupyter-kernel-laun...
# 11  https://github.com/nteract/jupyter-transport-w...
# 12           https://github.com/nteract/ipython-paths
# 13      https://github.com/nteract/transformime-react
# 14              https://github.com/nteract/commutable
# 15  https://github.com/nteract/react-jupyter-displ...
# 16   https://github.com/nteract/enchannel-zmq-backend
# 17               https://github.com/nteract/enchannel
# 18      https://github.com/nteract/notebook-test-data
# 19                     https://github.com/nteract/ick
# 20        https://github.com/nteract/terminal-sidecar
# 21             https://github.com/nteract/kernelspecs
# 22             https://github.com/nteract/spawnteract
# 23                  https://github.com/nteract/design
# 24                   https://github.com/nteract/specs
# 25            https://github.com/nteract/kernel-relay
# 26  https://github.com/nteract/enchannel-socketio-...
# 27                    https://github.com/nteract/docs
# 28                   https://github.com/nteract/logos
# 29     https://github.com/nteract/enchannel-in-memory
# ..                                                ...
# 31           https://github.com/nteract/ansi-to-react
# 32     https://github.com/nteract/transformime-marked
# 33        https://github.com/nteract/mathjax-electron
# 34                  https://github.com/nteract/assets
# 35              https://github.com/nteract/associator
# 36        https://github.com/nteract/notebook-preview
# 37                  https://github.com/nteract/naming
# 38             https://github.com/nteract/initiatives
# 39           https://github.com/nteract/term-launcher
# 40         https://github.com/nteract/meeting-minutes
# 41    https://github.com/nteract/zmq-prebuilt-testing
# 42            https://github.com/nteract/oauth-server
# 43              https://github.com/nteract/nteract.io
# 44              https://github.com/nteract/zmq-static
# 45                 https://github.com/nteract/inodejs
# 46               https://github.com/nteract/tick-tock
# 47              https://github.com/nteract/rx-jupyter
# 48              https://github.com/nteract/libzmq-win
# 49         https://github.com/nteract/commutable-perf
# 50               https://github.com/nteract/plotly.js
# 51                    https://github.com/nteract/vega
# 52                https://github.com/nteract/commuter
# 53            https://github.com/nteract/snakestagram
# 54       https://github.com/nteract/commutable-models
# 55          https://github.com/nteract/minimal-plotly
# 56          https://github.com/nteract/desktop-manual
# 57               https://github.com/nteract/papermill
# 58                 https://github.com/nteract/cabinet
# 59              https://github.com/nteract/papermillr
# 60                    https://github.com/nteract/vdom
#
#                                           description              pushedAt  \
# 0   :speedboat: Little side display of Jupyter ker...  2017-07-19T16:46:35Z
# 1   :atom: Run code interactively, inspect data, a...  2017-12-13T15:56:37Z
# 2   :city_sunrise: Pure JavaScript implementation ...  2017-07-19T16:46:33Z
# 3                   📘 Desktop notebook app + packages  2017-12-13T22:00:31Z
# 4                  :octocat: GitHub Pages for nteract  2017-04-29T01:16:19Z
# 5   :no_entry_sign: Prototype Web Component for Ju...  2017-01-20T21:50:00Z
# 6              :truck: Mimetype + data -> HTMLElement  2017-08-22T00:25:06Z
# 7   :no_entry_sign: Transformers for Jupyter-speci...  2017-01-20T21:52:14Z
# 8     :no_entry_sign: Transformer using commonmark.js  2017-01-20T21:52:08Z
# 9         A tool for interacting with Jupyter kernels  2017-01-20T21:50:17Z
# 10   Launches Jupyter kernels from a Node environment  2017-01-20T21:50:06Z
# 11  A thin wrapper abstracting over ZMQ and (evenu...  2017-01-20T21:50:22Z
# 12  :city_sunset: Paths for IPython before Jupyter...  2017-01-20T22:17:33Z
# 13                 🚫 Mimetype + data -> React Element  2017-05-08T22:49:40Z
# 14  :recycle: Operations for Immutable Notebook Do...  2017-05-08T22:50:42Z
# 15  :bar_chart: Jupyter Display Area as a React Co...  2017-05-09T20:48:44Z
# 16  :currency_exchange: Channeling Jupyter over zm...  2017-08-17T16:08:44Z
# 17  :currency_exchange: standardizing how a fronte...  2017-08-13T20:33:10Z
# 18  :books: Jupyter notebook test data. Feel free ...  2017-01-21T15:41:21Z
# 19  :izakaya_lantern: Interactive Console Experiments  2017-01-20T22:13:54Z
# 20      :speedboat: Jupyter Sidecar, in the terminal!  2017-01-20T21:51:56Z
# 21  :card_index: Find Jupyter kernelspecs on a system  2017-08-10T17:38:38Z
# 22          :children_crossing: Spawn Jupyter Kernels  2017-08-10T18:35:55Z
# 23             :pencil2: Mocking up nteract UI and UX  2017-07-18T20:15:31Z
# 24  :bookmark_tabs: Specifications for APIs, proce...  2016-06-14T22:59:50Z
# 25    :runner: socketio-zmq relay for Jupyter kernels  2017-01-20T21:50:27Z
# 26  :electric_plug: enchannel powered by socket.io...  2017-01-20T21:49:34Z
# 27  :notebook_with_decorative_cover: docs are awesome  2017-06-20T18:19:30Z
# 28  :sparkles: A place to collaborate on nteract l...  2017-07-06T21:24:37Z
# 29             :computer: In memory enchannel backend  2017-01-20T21:49:23Z
# ..                                                ...                   ...
# 31                          :guardsman: ANSI to React  2017-08-15T18:20:33Z
# 32                 :cyclone: Transformer using marked  2017-01-20T21:52:19Z
# 33  :symbols::electron: A trimmed down version of ...  2017-08-09T19:52:09Z
# 34        :package: static assets for nteract/nteract  2017-11-17T00:56:18Z
# 29  2016-03-07T01:58:20Z
# ..                   ...
# 31  2016-03-19T20:50:05Z
# 32  2016-04-01T22:11:08Z
# 33  2016-04-11T19:31:35Z
# 34  2016-04-14T18:20:00Z
# 35  2016-04-26T23:25:03Z
# 36  2016-04-27T01:32:22Z
# 37  2016-05-16T03:05:12Z
# 38  2016-07-08T19:37:59Z
# 39  2016-09-04T19:58:57Z
# 40  2016-09-08T22:05:59Z
# 41  2016-09-16T07:28:43Z
# 42  2016-09-24T21:55:19Z
# 43  2016-09-25T21:08:32Z
# 44  2016-09-30T07:54:31Z
# 45  2016-10-04T07:43:25Z
# 46  2016-10-08T03:19:29Z
# 47  2016-10-11T20:07:53Z
# 48  2016-10-24T17:01:23Z
# 49  2016-11-09T18:35:58Z
# 50  2016-12-26T21:21:29Z
# 51  2016-12-26T21:30:07Z
# 52  2017-01-03T22:23:32Z
# 53  2017-01-10T21:13:57Z
# 54  2017-01-13T19:46:05Z
# 55  2017-04-11T14:40:47Z
# 56  2017-06-01T19:37:46Z
# 57  2017-07-06T17:17:53Z
# 58  2017-07-27T22:33:25Z
# 59  2017-07-28T00:45:10Z
# 60  2017-08-30T18:31:57Z
#
# [61 rows x 5 columns]

# %%
# Top 10 repos by latest activity (pushedAt)
sorted_df = repos.sort_values(by=['pushedAt'], ascending=False)
sorted_df.head(10)
# Out:
#             name                                      url  \
# 3        nteract       https://github.com/nteract/nteract
# 1       hydrogen      https://github.com/nteract/hydrogen
# 57     papermill     https://github.com/nteract/papermill
# 52      commuter      https://github.com/nteract/commuter
# 60          vdom          https://github.com/nteract/vdom
# 34        assets        https://github.com/nteract/assets
# 58       cabinet       https://github.com/nteract/cabinet
# 43    nteract.io    https://github.com/nteract/nteract.io
# 47    rx-jupyter    https://github.com/nteract/rx-jupyter
# 6   transformime  https://github.com/nteract/transformime
#
#                                           description              pushedAt  \
# 3                   📘 Desktop notebook app + packages  2017-12-13T22:00:31Z
# 1   :atom: Run code interactively, inspect data, a...  2017-12-13T15:56:37Z
# 57     📚 Parameterize, execute, and analyze notebooks  2017-12-08T05:50:00Z
# 52           🚎 share, publish, and discover notebooks  2017-11-24T18:30:57Z
# 60                                  🎄 VDOM for Python  2017-11-21T17:40:54Z
# 34        :package: static assets for nteract/nteract  2017-11-17T00:56:18Z
# 58        📕 Exploring a new notebook container format  2017-11-01T20:46:05Z
# 43                            :mega: Our site! :mega:  2017-10-29T20:31:38Z
# 47     🎈 RxJS 5 bindings for the Jupyter Notebook API  2017-10-29T20:07:22Z
# 6              :truck: Mimetype + data -> HTMLElement  2017-08-22T00:25:06Z
#
#                createdAt
# 3   2015-06-15T23:21:49Z
# 1   2015-05-11T01:16:55Z
# 57  2017-07-06T17:17:53Z
# 52  2017-01-03T22:23:32Z
# 60  2017-08-30T18:31:57Z
# 34  2016-04-14T18:20:00Z
# 58  2017-07-27T22:33:25Z
# 43  2016-09-25T21:08:32Z
# 47  2016-10-11T20:07:53Z
# 6   2015-07-11T21:44:26Z

# %%
# output data to a csv
# df.to_csv('issue_report.csv')
