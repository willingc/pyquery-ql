# %% [markdown]
# # Background information on repos
#
# Supports Python 3.6+

# %%
import csv
import json
import os
import pprint

import requests

# %%
# get api token and set authorization
api_token = os.environ['GITHUB_API_TOKEN']
headers = {'Authorization': f'token {api_token}'}

# %%
# set url to a graphql endpoint
url = 'https://api.github.com/graphql'

# %%
# add a json query
query = """
{
  organization(login: "jupyterhub") {
    name
    repositories(first: 30) {
      nodes {
        name
        url
        description
        id
        pushedAt
        createdAt
      }
    }
  }
}
"""

# %%
# submit the request
r = requests.post(url=url, json={'query': query}, headers=headers)

# %%
result = r.json()
result
# Out:
# {'data': {'organization': {'name': 'JupyterHub',
#    'repositories': {'nodes': [{'createdAt': '2014-06-12T23:22:10Z',
#       'description': 'Multi-user server for Jupyter notebooks',
#       'id': 'MDEwOlJlcG9zaXRvcnkyMDc4NTk4Ng==',
#       'name': 'jupyterhub',
#       'pushedAt': '2017-12-12T13:38:18Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub'},
#      {'createdAt': '2014-08-25T22:28:59Z',
#       'description': 'node-http-proxy plus a REST API',
#       'id': 'MDEwOlJlcG9zaXRvcnkyMzMzMDkwMw==',
#       'name': 'configurable-http-proxy',
#       'pushedAt': '2017-12-12T03:34:38Z',
#       'url': 'https://github.com/jupyterhub/configurable-http-proxy'},
#      {'createdAt': '2014-09-23T21:37:06Z',
#       'description': 'OAuth + JupyterHub Authenticator = OAuthenticator',
#       'id': 'MDEwOlJlcG9zaXRvcnkyNDM5MDI4Mw==',
#       'name': 'oauthenticator',
#       'pushedAt': '2017-12-13T13:43:14Z',
#       'url': 'https://github.com/jupyterhub/oauthenticator'},
#      {'createdAt': '2014-09-26T20:08:26Z',
#       'description': 'Spawns JupyterHub single user servers in Docker containers ',
#       'id': 'MDEwOlJlcG9zaXRvcnkyNDUxMzc5OA==',
#       'name': 'dockerspawner',
#       'pushedAt': '2017-09-15T12:04:52Z',
#       'url': 'https://github.com/jupyterhub/dockerspawner'},
#      {'createdAt': '2014-11-24T23:21:36Z',
#       'description': 'Spawn JupyterHub single-user servers with sudo',
#       'id': 'MDEwOlJlcG9zaXRvcnkyNzA5OTkwMg==',
#       'name': 'sudospawner',
#       'pushedAt': '2017-11-22T15:00:03Z',
#       'url': 'https://github.com/jupyterhub/sudospawner'},
#      {'createdAt': '2015-10-27T03:53:10Z',
#       'description': 'Custom Spawner for Jupyterhub to start servers in batch scheduled systems',
#       'id': 'MDEwOlJlcG9zaXRvcnk0NTAxNTY5Mw==',
#       'name': 'batchspawner',
#       'pushedAt': '2017-11-29T21:53:39Z',
#       'url': 'https://github.com/jupyterhub/batchspawner'},
#      {'createdAt': '2015-11-21T07:02:52Z',
#       'description': 'Kubernetes spawner for JupyterHub',
#       'id': 'MDEwOlJlcG9zaXRvcnk0NjYwNDk4OA==',
#       'name': 'kubespawner',
#       'pushedAt': '2017-12-09T15:40:26Z',
#       'url': 'https://github.com/jupyterhub/kubespawner'},
#      {'createdAt': '2016-01-17T05:11:49Z',
#       'description': 'LDAP Authenticator Plugin for Jupyter',
#       'id': 'MDEwOlJlcG9zaXRvcnk0OTgwNDAyOA==',
#       'name': 'ldapauthenticator',
#       'pushedAt': '2017-10-13T11:04:40Z',
#       'url': 'https://github.com/jupyterhub/ldapauthenticator'},
#      {'createdAt': '2016-04-14T13:53:14Z',
#       'description': 'Reference deployment of JupyterHub with docker',
#       'id': 'MDEwOlJlcG9zaXRvcnk1NjI0MTUzMg==',
#       'name': 'jupyterhub-deploy-docker',
#       'pushedAt': '2017-10-30T10:42:06Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub-deploy-docker'},
#      {'createdAt': '2016-04-14T13:56:15Z',
#       'description': 'Reference deployment of JupyterHub and nbgrader on a single server',
#       'id': 'MDEwOlJlcG9zaXRvcnk1NjI0MTc3Nw==',
#       'name': 'jupyterhub-deploy-teaching',
#       'pushedAt': '2017-10-30T12:02:07Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub-deploy-teaching'},
#      {'createdAt': '2016-05-11T07:42:51Z',
#       'description': 'Tutorial materials for deploying JupyterHub',
#       'id': 'MDEwOlJlcG9zaXRvcnk1ODUyNDIyNw==',
#       'name': 'jupyterhub-tutorial',
#       'pushedAt': '2017-08-26T14:23:03Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub-tutorial'},
#      {'createdAt': '2016-07-25T23:26:21Z',
#       'description': 'Documented examples of Jupyterhub deployment in HPC settings',
#       'id': 'MDEwOlJlcG9zaXRvcnk2NDE3NDQ5Nw==',
#       'name': 'jupyterhub-deploy-hpc',
#       'pushedAt': '2017-08-04T11:23:45Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub-deploy-hpc'},
#      {'createdAt': '2016-09-06T07:20:44Z',
#       'description': 'Spawn JupyterHub single-user notebook servers with systemd',
#       'id': 'MDEwOlJlcG9zaXRvcnk2NzQ4MzY4NA==',
#       'name': 'systemdspawner',
#       'pushedAt': '2017-10-28T20:38:37Z',
#       'url': 'https://github.com/jupyterhub/systemdspawner'},
#      {'createdAt': '2016-09-21T21:48:31Z',
#       'description': 'Mechanism for runtime configuration of spawners for JupyterHub',
#       'id': 'MDEwOlJlcG9zaXRvcnk2ODg2MDQxNg==',
#       'name': 'wrapspawner',
#       'pushedAt': '2017-10-20T23:14:28Z',
#       'url': 'https://github.com/jupyterhub/wrapspawner'},
#      {'createdAt': '2016-10-17T17:56:01Z',
#       'description': 'JupyterLab extension for running JupyterLab with JupyterHub',
#       'id': 'MDEwOlJlcG9zaXRvcnk3MTE2NTk5MQ==',
#       'name': 'jupyterlab-hub',
#       'pushedAt': '2017-12-08T10:40:50Z',
#       'url': 'https://github.com/jupyterhub/jupyterlab-hub'},
#      {'createdAt': '2016-10-18T22:02:06Z',
#       'description': 'Jupyter notebook server extension to proxy web services.',
#       'id': 'MDEwOlJlcG9zaXRvcnk3MTI5NTE2NA==',
#       'name': 'nbserverproxy',
#       'pushedAt': '2017-12-02T21:23:46Z',
#       'url': 'https://github.com/jupyterhub/nbserverproxy'},
#      {'createdAt': '2016-11-09T19:03:08Z',
#       'description': 'Example for experimenting with how JupyterHub can be configured to work with Kerberos',
#       'id': 'MDEwOlJlcG9zaXRvcnk3MzMxMjgyMA==',
#       'name': 'jupyterhub-example-kerberos',
#       'pushedAt': '2017-10-17T02:05:39Z',
#       'url': 'https://github.com/jupyterhub/jupyterhub-example-kerberos'},
#      {'createdAt': '2016-11-12T21:43:43Z',
#       'description': 'A directory sharing service for JupyterHub',
#       'id': 'MDEwOlJlcG9zaXRvcnk3MzU4MDIxMw==',
#       'name': 'hubshare',
#       'pushedAt': '2017-08-04T11:21:51Z',
#       'url': 'https://github.com/jupyterhub/hubshare'},
#      {'createdAt': '2016-12-09T06:26:18Z',
#       'description': 'Jupyter extensions for running an RStudio rsession proxy',
#       'id': 'MDEwOlJlcG9zaXRvcnk3NjAwODA5MA==',
#       'name': 'nbrsessionproxy',
#       'pushedAt': '2017-12-02T21:27:16Z',
#       'url': 'https://github.com/jupyterhub/nbrsessionproxy'},
#      {'createdAt': '2016-12-30T02:42:15Z',
#       'description': 'JupyterHub authenticator that hands out temporary accounts for everyone. For use in tmpnb.org',
#       'id': 'MDEwOlJlcG9zaXRvcnk3NzY1NDc4MA==',
#       'name': 'tmpauthenticator',
#       'pushedAt': '2017-11-03T11:04:15Z',
#       'url': 'https://github.com/jupyterhub/tmpauthenticator'},
#      {'createdAt': '2017-04-10T19:25:35Z',
#       'description': 'Resources for deploying JupyterHub to a Kubernetes Cluster',
#       'id': 'MDEwOlJlcG9zaXRvcnk4Nzg0OTM3MQ==',
#       'name': 'zero-to-jupyterhub-k8s',
#       'pushedAt': '2017-12-13T18:30:59Z',
#       'url': 'https://github.com/jupyterhub/zero-to-jupyterhub-k8s'},
#      {'createdAt': '2017-04-11T02:11:42Z',
#       'description': 'A store of Helm chart tarballs for deploying JupyterHub and BinderHub on a Kubernetes cluster',
#       'id': 'MDEwOlJlcG9zaXRvcnk4Nzg3NzU2OQ==',
#       'name': 'helm-chart',
#       'pushedAt': '2017-12-13T20:32:20Z',
#       'url': 'https://github.com/jupyterhub/helm-chart'},
#      {'createdAt': '2017-04-26T00:28:26Z',
#       'description': 'Deterministically build docker images from a git repository + commit',
#       'id': 'MDEwOlJlcG9zaXRvcnk4OTQxOTM2OA==',
#       'name': 'binderhub',
#       'pushedAt': '2017-12-13T18:42:41Z',
#       'url': 'https://github.com/jupyterhub/binderhub'},
#      {'createdAt': '2017-05-22T19:17:42Z',
#       'description': 'Deployment config files for mybinder.org',
#       'id': 'MDEwOlJlcG9zaXRvcnk5MjA5MDY5MA==',
#       'name': 'mybinder.org-deploy',
#       'pushedAt': '2017-12-13T12:03:57Z',
#       'url': 'https://github.com/jupyterhub/mybinder.org-deploy'},
#      {'createdAt': '2017-08-17T05:21:49Z',
#       'description': 'Binder metapackage for usage, docs, and chat',
#       'id': 'MDEwOlJlcG9zaXRvcnkxMDA1NjQ1MTU=',
#       'name': 'binder',
#       'pushedAt': '2017-12-12T22:29:07Z',
#       'url': 'https://github.com/jupyterhub/binder'},
#      {'createdAt': '2017-08-30T09:12:22Z',
#       'description': 'Null Authenticator for JupyterHub instances that should have no login mechanism',
#       'id': 'MDEwOlJlcG9zaXRvcnkxMDE4NjE1Nzk=',
#       'name': 'nullauthenticator',
#       'pushedAt': '2017-10-11T16:19:04Z',
#       'url': 'https://github.com/jupyterhub/nullauthenticator'},
#      {'createdAt': '2017-12-07T20:10:06Z',
#       'description': 'A repository for team interaction, syncing, and handling meeting notes across the JupyterHub ecosystem.',
#       'id': 'MDEwOlJlcG9zaXRvcnkxMTM0OTM4MzE=',
#       'name': 'team-compass',
#       'pushedAt': '2017-12-12T17:29:51Z',
#       'url': 'https://github.com/jupyterhub/team-compass'}]}}}}

# %%
import pandas as pd

# %%
repos = pd.DataFrame(result['data']['organization']['repositories']['nodes'], columns=['name', 'url', 'description', 'pushedAt', 'createdAt'])

# %%
repos
# Out:
#                            name  \
# 0                    jupyterhub
# 1       configurable-http-proxy
# 2                oauthenticator
# 3                 dockerspawner
# 4                   sudospawner
# 5                  batchspawner
# 6                   kubespawner
# 7             ldapauthenticator
# 8      jupyterhub-deploy-docker
# 9    jupyterhub-deploy-teaching
# 10          jupyterhub-tutorial
# 11        jupyterhub-deploy-hpc
# 12               systemdspawner
# 13                  wrapspawner
# 14               jupyterlab-hub
# 15                nbserverproxy
# 16  jupyterhub-example-kerberos
# 17                     hubshare
# 18              nbrsessionproxy
# 19             tmpauthenticator
# 20       zero-to-jupyterhub-k8s
# 21                   helm-chart
# 22                    binderhub
# 23          mybinder.org-deploy
# 24                       binder
# 25            nullauthenticator
# 26                 team-compass
#
#                                                   url  \
# 0            https://github.com/jupyterhub/jupyterhub
# 1   https://github.com/jupyterhub/configurable-htt...
# 2        https://github.com/jupyterhub/oauthenticator
# 3         https://github.com/jupyterhub/dockerspawner
# 4           https://github.com/jupyterhub/sudospawner
# 5          https://github.com/jupyterhub/batchspawner
# 6           https://github.com/jupyterhub/kubespawner
# 7     https://github.com/jupyterhub/ldapauthenticator
# 8   https://github.com/jupyterhub/jupyterhub-deplo...
# 9   https://github.com/jupyterhub/jupyterhub-deplo...
# 10  https://github.com/jupyterhub/jupyterhub-tutorial
# 11  https://github.com/jupyterhub/jupyterhub-deplo...
# 12       https://github.com/jupyterhub/systemdspawner
# 13          https://github.com/jupyterhub/wrapspawner
# 14       https://github.com/jupyterhub/jupyterlab-hub
# 15        https://github.com/jupyterhub/nbserverproxy
# 16  https://github.com/jupyterhub/jupyterhub-examp...
# 17             https://github.com/jupyterhub/hubshare
# 18      https://github.com/jupyterhub/nbrsessionproxy
# 19     https://github.com/jupyterhub/tmpauthenticator
# 20  https://github.com/jupyterhub/zero-to-jupyterh...
# 21           https://github.com/jupyterhub/helm-chart
# 22            https://github.com/jupyterhub/binderhub
# 23  https://github.com/jupyterhub/mybinder.org-deploy
# 24               https://github.com/jupyterhub/binder
# 25    https://github.com/jupyterhub/nullauthenticator
# 26         https://github.com/jupyterhub/team-compass
#
#                                           description              pushedAt  \
# 0             Multi-user server for Jupyter notebooks  2017-12-12T13:38:18Z
# 1                     node-http-proxy plus a REST API  2017-12-12T03:34:38Z
# 2   OAuth + JupyterHub Authenticator = OAuthenticator  2017-12-13T13:43:14Z
# 3   Spawns JupyterHub single user servers in Docke...  2017-09-15T12:04:52Z
# 4      Spawn JupyterHub single-user servers with sudo  2017-11-22T15:00:03Z
# 5   Custom Spawner for Jupyterhub to start servers...  2017-11-29T21:53:39Z
# 6                   Kubernetes spawner for JupyterHub  2017-12-09T15:40:26Z
# 7               LDAP Authenticator Plugin for Jupyter  2017-10-13T11:04:40Z
# 8      Reference deployment of JupyterHub with docker  2017-10-30T10:42:06Z
# 9   Reference deployment of JupyterHub and nbgrade...  2017-10-30T12:02:07Z
# 10        Tutorial materials for deploying JupyterHub  2017-08-26T14:23:03Z
# 11  Documented examples of Jupyterhub deployment i...  2017-08-04T11:23:45Z
# 12  Spawn JupyterHub single-user notebook servers ...  2017-10-28T20:38:37Z
# 13  Mechanism for runtime configuration of spawner...  2017-10-20T23:14:28Z
# 14  JupyterLab extension for running JupyterLab wi...  2017-12-08T10:40:50Z
# 15  Jupyter notebook server extension to proxy web...  2017-12-02T21:23:46Z
# 16  Example for experimenting with how JupyterHub ...  2017-10-17T02:05:39Z
# 17         A directory sharing service for JupyterHub  2017-08-04T11:21:51Z
# 18  Jupyter extensions for running an RStudio rses...  2017-12-02T21:27:16Z
# 19  JupyterHub authenticator that hands out tempor...  2017-11-03T11:04:15Z
# 20  Resources for deploying JupyterHub to a Kubern...  2017-12-13T18:30:59Z
# 21  A store of Helm chart tarballs for deploying J...  2017-12-13T20:32:20Z
# 22  Deterministically build docker images from a g...  2017-12-13T18:42:41Z
# 23           Deployment config files for mybinder.org  2017-12-13T12:03:57Z
# 24       Binder metapackage for usage, docs, and chat  2017-12-12T22:29:07Z
# 25  Null Authenticator for JupyterHub instances th...  2017-10-11T16:19:04Z
# 26  A repository for team interaction, syncing, an...  2017-12-12T17:29:51Z
#
#                createdAt
# 0   2014-06-12T23:22:10Z
# 1   2014-08-25T22:28:59Z
# 2   2014-09-23T21:37:06Z
# 3   2014-09-26T20:08:26Z
# 4   2014-11-24T23:21:36Z
# 5   2015-10-27T03:53:10Z
# 6   2015-11-21T07:02:52Z
# 7   2016-01-17T05:11:49Z
# 8   2016-04-14T13:53:14Z
# 9   2016-04-14T13:56:15Z
# 10  2016-05-11T07:42:51Z
# 11  2016-07-25T23:26:21Z
# 12  2016-09-06T07:20:44Z
# 13  2016-09-21T21:48:31Z
# 14  2016-10-17T17:56:01Z
# 15  2016-10-18T22:02:06Z
# 16  2016-11-09T19:03:08Z
# 17  2016-11-12T21:43:43Z
# 18  2016-12-09T06:26:18Z
# 19  2016-12-30T02:42:15Z
# 20  2017-04-10T19:25:35Z
# 21  2017-04-11T02:11:42Z
# 22  2017-04-26T00:28:26Z
# 23  2017-05-22T19:17:42Z
# 24  2017-08-17T05:21:49Z
# 25  2017-08-30T09:12:22Z
# 26  2017-12-07T20:10:06Z

# %% [markdown]
# ### Reports

# %%
# By repo name
sorted_df = repos.sort_values(by=['name'])
sorted_df
# Out:
#                            name  \
# 5                  batchspawner
# 24                       binder
# 22                    binderhub
# 1       configurable-http-proxy
# 3                 dockerspawner
# 21                   helm-chart
# 17                     hubshare
# 0                    jupyterhub
# 8      jupyterhub-deploy-docker
# 11        jupyterhub-deploy-hpc
# 9    jupyterhub-deploy-teaching
# 16  jupyterhub-example-kerberos
# 10          jupyterhub-tutorial
# 14               jupyterlab-hub
# 6                   kubespawner
# 7             ldapauthenticator
# 23          mybinder.org-deploy
# 18              nbrsessionproxy
# 15                nbserverproxy
# 25            nullauthenticator
# 2                oauthenticator
# 4                   sudospawner
# 12               systemdspawner
# 26                 team-compass
# 19             tmpauthenticator
# 13                  wrapspawner
# 20       zero-to-jupyterhub-k8s
#
#                                                   url  \
# 5          https://github.com/jupyterhub/batchspawner
# 24               https://github.com/jupyterhub/binder
# 22            https://github.com/jupyterhub/binderhub
# 1   https://github.com/jupyterhub/configurable-htt...
# 3         https://github.com/jupyterhub/dockerspawner
# 21           https://github.com/jupyterhub/helm-chart
# 17             https://github.com/jupyterhub/hubshare
# 0            https://github.com/jupyterhub/jupyterhub
# 8   https://github.com/jupyterhub/jupyterhub-deplo...
# 11  https://github.com/jupyterhub/jupyterhub-deplo...
# 9   https://github.com/jupyterhub/jupyterhub-deplo...
# 16  https://github.com/jupyterhub/jupyterhub-examp...
# 10  https://github.com/jupyterhub/jupyterhub-tutorial
# 14       https://github.com/jupyterhub/jupyterlab-hub
# 6           https://github.com/jupyterhub/kubespawner
# 7     https://github.com/jupyterhub/ldapauthenticator
# 23  https://github.com/jupyterhub/mybinder.org-deploy
# 18      https://github.com/jupyterhub/nbrsessionproxy
# 15        https://github.com/jupyterhub/nbserverproxy
# 25    https://github.com/jupyterhub/nullauthenticator
# 2        https://github.com/jupyterhub/oauthenticator
# 4           https://github.com/jupyterhub/sudospawner
# 12       https://github.com/jupyterhub/systemdspawner
# 26         https://github.com/jupyterhub/team-compass
# 19     https://github.com/jupyterhub/tmpauthenticator
# 13          https://github.com/jupyterhub/wrapspawner
# 20  https://github.com/jupyterhub/zero-to-jupyterh...
#
#                                           description              pushedAt  \
# 5   Custom Spawner for Jupyterhub to start servers...  2017-11-29T21:53:39Z
# 24       Binder metapackage for usage, docs, and chat  2017-12-12T22:29:07Z
# 22  Deterministically build docker images from a g...  2017-12-13T18:42:41Z
# 1                     node-http-proxy plus a REST API  2017-12-12T03:34:38Z
# 3   Spawns JupyterHub single user servers in Docke...  2017-09-15T12:04:52Z
# 21  A store of Helm chart tarballs for deploying J...  2017-12-13T20:32:20Z
# 17         A directory sharing service for JupyterHub  2017-08-04T11:21:51Z
# 0             Multi-user server for Jupyter notebooks  2017-12-12T13:38:18Z
# 8      Reference deployment of JupyterHub with docker  2017-10-30T10:42:06Z
# 11  Documented examples of Jupyterhub deployment i...  2017-08-04T11:23:45Z
# 9   Reference deployment of JupyterHub and nbgrade...  2017-10-30T12:02:07Z
# 16  Example for experimenting with how JupyterHub ...  2017-10-17T02:05:39Z
# 10        Tutorial materials for deploying JupyterHub  2017-08-26T14:23:03Z
# 14  JupyterLab extension for running JupyterLab wi...  2017-12-08T10:40:50Z
# 6                   Kubernetes spawner for JupyterHub  2017-12-09T15:40:26Z
# 7               LDAP Authenticator Plugin for Jupyter  2017-10-13T11:04:40Z
# 23           Deployment config files for mybinder.org  2017-12-13T12:03:57Z
# 18  Jupyter extensions for running an RStudio rses...  2017-12-02T21:27:16Z
# 15  Jupyter notebook server extension to proxy web...  2017-12-02T21:23:46Z
# 25  Null Authenticator for JupyterHub instances th...  2017-10-11T16:19:04Z
# 2   OAuth + JupyterHub Authenticator = OAuthenticator  2017-12-13T13:43:14Z
# 4      Spawn JupyterHub single-user servers with sudo  2017-11-22T15:00:03Z
# 12  Spawn JupyterHub single-user notebook servers ...  2017-10-28T20:38:37Z
# 26  A repository for team interaction, syncing, an...  2017-12-12T17:29:51Z
# 19  JupyterHub authenticator that hands out tempor...  2017-11-03T11:04:15Z
# 13  Mechanism for runtime configuration of spawner...  2017-10-20T23:14:28Z
# 20  Resources for deploying JupyterHub to a Kubern...  2017-12-13T18:30:59Z
#
#                createdAt
# 5   2015-10-27T03:53:10Z
# 24  2017-08-17T05:21:49Z
# 22  2017-04-26T00:28:26Z
# 1   2014-08-25T22:28:59Z
# 3   2014-09-26T20:08:26Z
# 21  2017-04-11T02:11:42Z
# 17  2016-11-12T21:43:43Z
# 0   2014-06-12T23:22:10Z
# 8   2016-04-14T13:53:14Z
# 11  2016-07-25T23:26:21Z
# 9   2016-04-14T13:56:15Z
# 16  2016-11-09T19:03:08Z
# 10  2016-05-11T07:42:51Z
# 14  2016-10-17T17:56:01Z
# 6   2015-11-21T07:02:52Z
# 7   2016-01-17T05:11:49Z
# 23  2017-05-22T19:17:42Z
# 18  2016-12-09T06:26:18Z
# 15  2016-10-18T22:02:06Z
# 25  2017-08-30T09:12:22Z
# 2   2014-09-23T21:37:06Z
# 4   2014-11-24T23:21:36Z
# 12  2016-09-06T07:20:44Z
# 26  2017-12-07T20:10:06Z
# 19  2016-12-30T02:42:15Z
# 13  2016-09-21T21:48:31Z
# 20  2017-04-10T19:25:35Z

# %%
# by creation date
sorted_df = repos.sort_values(by=['createdAt'])
sorted_df
# Out:
#                            name  \
# 0                    jupyterhub
# 1       configurable-http-proxy
# 2                oauthenticator
# 3                 dockerspawner
# 4                   sudospawner
# 5                  batchspawner
# 6                   kubespawner
# 7             ldapauthenticator
# 8      jupyterhub-deploy-docker
# 9    jupyterhub-deploy-teaching
# 10          jupyterhub-tutorial
# 11        jupyterhub-deploy-hpc
# 12               systemdspawner
# 13                  wrapspawner
# 14               jupyterlab-hub
# 15                nbserverproxy
# 16  jupyterhub-example-kerberos
# 17                     hubshare
# 18              nbrsessionproxy
# 19             tmpauthenticator
# 20       zero-to-jupyterhub-k8s
# 21                   helm-chart
# 22                    binderhub
# 23          mybinder.org-deploy
# 24                       binder
# 25            nullauthenticator
# 26                 team-compass
#
#                                                   url  \
# 0            https://github.com/jupyterhub/jupyterhub
# 1   https://github.com/jupyterhub/configurable-htt...
# 2        https://github.com/jupyterhub/oauthenticator
# 3         https://github.com/jupyterhub/dockerspawner
# 4           https://github.com/jupyterhub/sudospawner
# 5          https://github.com/jupyterhub/batchspawner
# 6           https://github.com/jupyterhub/kubespawner
# 7     https://github.com/jupyterhub/ldapauthenticator
# 8   https://github.com/jupyterhub/jupyterhub-deplo...
# 9   https://github.com/jupyterhub/jupyterhub-deplo...
# 10  https://github.com/jupyterhub/jupyterhub-tutorial
# 11  https://github.com/jupyterhub/jupyterhub-deplo...
# 12       https://github.com/jupyterhub/systemdspawner
# 13          https://github.com/jupyterhub/wrapspawner
# 14       https://github.com/jupyterhub/jupyterlab-hub
# 15        https://github.com/jupyterhub/nbserverproxy
# 16  https://github.com/jupyterhub/jupyterhub-examp...
# 17             https://github.com/jupyterhub/hubshare
# 18      https://github.com/jupyterhub/nbrsessionproxy
# 19     https://github.com/jupyterhub/tmpauthenticator
# 20  https://github.com/jupyterhub/zero-to-jupyterh...
# 21           https://github.com/jupyterhub/helm-chart
# 22            https://github.com/jupyterhub/binderhub
# 23  https://github.com/jupyterhub/mybinder.org-deploy
# 24               https://github.com/jupyterhub/binder
# 25    https://github.com/jupyterhub/nullauthenticator
# 26         https://github.com/jupyterhub/team-compass
#
#                                           description              pushedAt  \
# 0             Multi-user server for Jupyter notebooks  2017-12-12T13:38:18Z
# 1                     node-http-proxy plus a REST API  2017-12-12T03:34:38Z
# 2   OAuth + JupyterHub Authenticator = OAuthenticator  2017-12-13T13:43:14Z
# 3   Spawns JupyterHub single user servers in Docke...  2017-09-15T12:04:52Z
# 4      Spawn JupyterHub single-user servers with sudo  2017-11-22T15:00:03Z
# 5   Custom Spawner for Jupyterhub to start servers...  2017-11-29T21:53:39Z
# 6                   Kubernetes spawner for JupyterHub  2017-12-09T15:40:26Z
# 7               LDAP Authenticator Plugin for Jupyter  2017-10-13T11:04:40Z
# 8      Reference deployment of JupyterHub with docker  2017-10-30T10:42:06Z
# 9   Reference deployment of JupyterHub and nbgrade...  2017-10-30T12:02:07Z
# 10        Tutorial materials for deploying JupyterHub  2017-08-26T14:23:03Z
# 11  Documented examples of Jupyterhub deployment i...  2017-08-04T11:23:45Z
# 12  Spawn JupyterHub single-user notebook servers ...  2017-10-28T20:38:37Z
# 13  Mechanism for runtime configuration of spawner...  2017-10-20T23:14:28Z
# 14  JupyterLab extension for running JupyterLab wi...  2017-12-08T10:40:50Z
# 15  Jupyter notebook server extension to proxy web...  2017-12-02T21:23:46Z
# 16  Example for experimenting with how JupyterHub ...  2017-10-17T02:05:39Z
# 17         A directory sharing service for JupyterHub  2017-08-04T11:21:51Z
# 18  Jupyter extensions for running an RStudio rses...  2017-12-02T21:27:16Z
# 19  JupyterHub authenticator that hands out tempor...  2017-11-03T11:04:15Z
# 20  Resources for deploying JupyterHub to a Kubern...  2017-12-13T18:30:59Z
# 21  A store of Helm chart tarballs for deploying J...  2017-12-13T20:32:20Z
# 22  Deterministically build docker images from a g...  2017-12-13T18:42:41Z
# 23           Deployment config files for mybinder.org  2017-12-13T12:03:57Z
# 24       Binder metapackage for usage, docs, and chat  2017-12-12T22:29:07Z
# 25  Null Authenticator for JupyterHub instances th...  2017-10-11T16:19:04Z
# 26  A repository for team interaction, syncing, an...  2017-12-12T17:29:51Z
#
#                createdAt
# 0   2014-06-12T23:22:10Z
# 1   2014-08-25T22:28:59Z
# 2   2014-09-23T21:37:06Z
# 3   2014-09-26T20:08:26Z
# 4   2014-11-24T23:21:36Z
# 5   2015-10-27T03:53:10Z
# 6   2015-11-21T07:02:52Z
# 7   2016-01-17T05:11:49Z
# 8   2016-04-14T13:53:14Z
# 9   2016-04-14T13:56:15Z
# 10  2016-05-11T07:42:51Z
# 11  2016-07-25T23:26:21Z
# 12  2016-09-06T07:20:44Z
# 13  2016-09-21T21:48:31Z
# 14  2016-10-17T17:56:01Z
# 15  2016-10-18T22:02:06Z
# 16  2016-11-09T19:03:08Z
# 17  2016-11-12T21:43:43Z
# 18  2016-12-09T06:26:18Z
# 19  2016-12-30T02:42:15Z
# 20  2017-04-10T19:25:35Z
# 21  2017-04-11T02:11:42Z
# 22  2017-04-26T00:28:26Z
# 23  2017-05-22T19:17:42Z
# 24  2017-08-17T05:21:49Z
# 25  2017-08-30T09:12:22Z
# 26  2017-12-07T20:10:06Z

# %%
# output data to a csv
# df.to_csv('issue_report.csv')
