# %% [markdown]
# # nteract open issue and pr counts
# Send a graphql query to GitHub
# and work with files for reports.
#
# Supports Python 3.6+

# %%
import csv
import json
import os
import pprint

import requests

# %%
# get api token and set authorization
api_token = os.environ['GITHUB_API_TOKEN']
headers = {'Authorization': f'token {api_token}'}

# %%
# set url to a graphql endpoint
url = 'https://api.github.com/graphql'

# %%
# add a json query
query = """
{
  organization(login: "nteract") {
    repositories(first: 80) {
      nodes {
        name
        issues(first: 4) {
          nodes {
            number
            title
            createdAt
          }
        }
      }
    }
  }
}
"""

# %% [markdown]
# ### Make request and create json and csv files

# %%
# submit the request
r = requests.post(url=url, json={'query': query}, headers=headers)

# %%
# create a json file from response
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
# unpack the layers of json
nodes = r.json()['data']['organization']['repositories']['nodes']

unpacked = []
for node in nodes:
    unpacked.append(node)

# %%
unpacked
# Out:
# [{'issues': {'nodes': [{'createdAt': '2015-05-17T14:09:54Z',
#      'number': 1,
#      'title': 'Handle input on stdin'},
#     {'createdAt': '2015-06-16T14:01:14Z',
#      'number': 2,
#      'title': 'Installation Problems'},
#     {'createdAt': '2015-06-17T15:15:09Z',
#      'number': 6,
#      'title': 'Cannot build on Windows'},
#     {'createdAt': '2015-06-26T03:12:54Z',
#      'number': 8,
#      'title': 'Display area is launched for kernels that no longer exist'}]},
#   'name': 'sidecar'},
#  {'issues': {'nodes': [{'createdAt': '2015-05-18T03:34:11Z',
#      'number': 1,
#      'title': 'Awesome'},
#     {'createdAt': '2015-05-18T04:17:49Z',
#      'number': 2,
#      'title': 'Integrate with autocomplete plus'},
#     {'createdAt': '2015-05-18T04:20:26Z',
#      'number': 3,
#      'title': 'Plots are a bit constrained'},
#     {'createdAt': '2015-05-18T13:26:34Z',
#      'number': 5,
#      'title': "Uncaught TypeError: Cannot read property 'toLowerCase' of undefined"}]},
#   'name': 'hydrogen'},
#  {'issues': {'nodes': [{'createdAt': '2015-06-16T01:29:51Z',
#      'number': 1,
#      'title': 'Expose higher level interfaces'},
#     {'createdAt': '2015-06-18T22:37:14Z',
#      'number': 2,
#      'title': 'support ipython 2/3'},
#     {'createdAt': '2015-08-31T11:40:05Z',
#      'number': 4,
#      'title': 'Use the implementation in Hydrogen'},
#     {'createdAt': '2016-01-07T07:15:05Z',
#      'number': 5,
#      'title': 'Implement Jupyter Paths directly'}]},
#   'name': 'jupyter-paths'},
#  {'issues': {'nodes': [{'createdAt': '2015-12-24T06:00:59Z',
#      'number': 1,
#      'title': 'zmq for everyone'},
#     {'createdAt': '2015-12-24T06:06:13Z',
#      'number': 2,
#      'title': 'Scope/Roadmap'},
#     {'createdAt': '2016-01-01T16:14:29Z',
#      'number': 3,
#      'title': 'Notebook operations'},
#     {'createdAt': '2016-01-01T16:15:41Z',
#      'number': 4,
#      'title': 'Kernelspec operations'}]},
#   'name': 'nteract'},
#  {'issues': {'nodes': [{'createdAt': '2016-06-08T02:56:55Z',
#      'number': 5,
#      'title': 'Resources not loaded properly when refreshing after scrolling'},
#     {'createdAt': '2016-06-08T02:57:39Z',
#      'number': 6,
#      'title': 'Download buttons should emphasize that it is alpha software'},
#     {'createdAt': '2016-06-14T18:37:02Z',
#      'number': 11,
#      'title': 'What language does it support?'},
#     {'createdAt': '2016-08-11T15:41:55Z',
#      'number': 14,
#      'title': "Hero banner buttons don't work on mobile"}]},
#   'name': 'nteract.github.io'},
#  {'issues': {'nodes': [{'createdAt': '2015-07-11T17:56:18Z',
#      'number': 12,
#      'title': 'Live reload for development'},
#     {'createdAt': '2015-07-14T03:05:03Z',
#      'number': 17,
#      'title': 'Jupyter migration (meta issue)'},
#     {'createdAt': '2015-07-14T03:38:04Z',
#      'number': 18,
#      'title': 'Include fetch polyfill in demo'},
#     {'createdAt': '2015-07-22T22:57:21Z',
#      'number': 20,
#      'title': "Cannot read property 'ownerDocument' of null"}]},
#   'name': 'jupyter-display-area'},
#  {'issues': {'nodes': [{'createdAt': '2015-07-21T00:07:45Z',
#      'number': 17,
#      'title': '1.0.0 release'},
#     {'createdAt': '2015-07-23T17:05:23Z',
#      'number': 19,
#      'title': 'Renderer -> Transformer'},
#     {'createdAt': '2015-07-26T17:39:02Z',
#      'number': 27,
#      'title': 'HTML mimetype should execute script, or provide the option to do so.'},
#     {'createdAt': '2015-08-01T14:22:25Z',
#      'number': 29,
#      'title': 'Adapt tests to work across karma multi-browser runs'}]},
#   'name': 'transformime'},
#  {'issues': {'nodes': [{'createdAt': '2015-07-24T17:25:18Z',
#      'number': 2,
#      'title': 'Mimetypes to render to conform with notebook'}]},
#   'name': 'transformime-jupyter-transformers'},
#  {'issues': {'nodes': []}, 'name': 'transformime-commonmark'},
#  {'issues': {'nodes': []}, 'name': 'jupyter-session'},
#  {'issues': {'nodes': []}, 'name': 'jupyter-kernel-launcher'},
#  {'issues': {'nodes': []}, 'name': 'jupyter-transport-wrapper'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-20T17:45:50Z',
#      'number': 2,
#      'title': 'Provide the runtime directory'}]},
#   'name': 'ipython-paths'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-03T07:50:49Z',
#      'number': 1,
#      'title': 'Jupyter mimetypes'},
#     {'createdAt': '2016-03-13T08:30:08Z',
#      'number': 9,
#      'title': 'text/plain should interpret ANSI'},
#     {'createdAt': '2016-08-21T22:41:29Z',
#      'number': 17,
#      'title': 'Switch our Latex Transform to using mathjax-electron'},
#     {'createdAt': '2016-08-23T22:10:08Z',
#      'number': 18,
#      'title': 'Move this package into nteract/nteract'}]},
#   'name': 'transformime-react'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-08T14:57:08Z',
#      'number': 1,
#      'title': "What's in a name?"},
#     {'createdAt': '2016-01-08T16:41:36Z',
#      'number': 2,
#      'title': 'Different models and different users'},
#     {'createdAt': '2016-01-16T17:55:09Z',
#      'number': 6,
#      'title': 'Rely on notebook-test-data'},
#     {'createdAt': '2016-01-19T04:14:20Z',
#      'number': 8,
#      'title': 'Notebook format conversion'}]},
#   'name': 'commutable'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-10T04:49:47Z',
#      'number': 1,
#      'title': 'ConsoleText should create React Components'},
#     {'createdAt': '2016-01-19T04:36:17Z',
#      'number': 2,
#      'title': 'Write up example usage'},
#     {'createdAt': '2016-01-19T04:38:51Z',
#      'number': 3,
#      'title': 'Transforms should be a prop'},
#     {'createdAt': '2016-02-17T23:30:54Z',
#      'number': 6,
#      'title': 'Create an IFramed HTML output element'}]},
#   'name': 'react-jupyter-display-area'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-12T07:03:46Z',
#      'number': 1,
#      'title': 'Interface iterations'},
#     {'createdAt': '2016-01-13T05:10:17Z',
#      'number': 4,
#      'title': 'Add note about zmq installation'},
#     {'createdAt': '2016-01-19T18:17:31Z',
#      'number': 11,
#      'title': 'Switch to RxJS 5'},
#     {'createdAt': '2016-02-12T04:24:26Z',
#      'number': 15,
#      'title': 'Bump to RxJS 5.0 beta 2'}]},
#   'name': 'enchannel-zmq-backend'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-13T01:14:29Z',
#      'number': 1,
#      'title': 'Outline what this is about'},
#     {'createdAt': '2016-01-13T18:37:23Z',
#      'number': 3,
#      'title': 'Object.freeze() messages'},
#     {'createdAt': '2016-01-13T19:15:15Z',
#      'number': 4,
#      'title': 'Export 5 functions instead of 1'},
#     {'createdAt': '2016-02-29T18:14:15Z',
#      'number': 6,
#      'title': 'Should there be a spec for starting/stopping a kernel'}]},
#   'name': 'enchannel'},
#  {'issues': {'nodes': [{'createdAt': '2016-05-05T15:42:43Z',
#      'number': 3,
#      'title': 'Bring in nice, useful notebooks'}]},
#   'name': 'notebook-test-data'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-22T06:28:07Z',
#      'number': 3,
#      'title': 'Clean up connection file, connection'},
#     {'createdAt': '2016-01-22T06:29:37Z',
#      'number': 4,
#      'title': 'In[ ] and Out[ ]'},
#     {'createdAt': '2016-01-22T06:30:37Z', 'number': 5, 'title': 'Completion'},
#     {'createdAt': '2016-01-22T06:37:05Z',
#      'number': 6,
#      'title': 'Wonky prompt display'}]},
#   'name': 'ick'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-19T03:25:41Z',
#      'number': 1,
#      'title': 'Detect Running Kernels'},
#     {'createdAt': '2016-01-19T03:35:24Z',
#      'number': 3,
#      'title': 'Style output more appropriately'},
#     {'createdAt': '2016-01-19T04:44:20Z',
#      'number': 4,
#      'title': 'Detect iterm2 and display image directly'}]},
#   'name': 'terminal-sidecar'},
#  {'issues': {'nodes': [{'createdAt': '2016-02-03T03:07:59Z',
#      'number': 14,
#      'title': 'Problem: Object response is not jupyter kernelspec format'},
#     {'createdAt': '2016-05-21T11:59:22Z',
#      'number': 18,
#      'title': "Kernelspecs doesn't find python kernel from sys-dir"},
#     {'createdAt': '2017-04-24T13:29:39Z',
#      'number': 23,
#      'title': 'An in-range update of mocha is breaking the build 🚨'},
#     {'createdAt': '2017-05-16T22:48:38Z',
#      'number': 24,
#      'title': 'The title of this repo has a typo in it!'}]},
#   'name': 'kernelspecs'},
#  {'issues': {'nodes': [{'createdAt': '2016-01-23T01:48:28Z',
#      'number': 1,
#      'title': 'Rely on node-temp for cleaning up kernel files?'},
#     {'createdAt': '2016-08-16T04:50:54Z',
#      'number': 14,
#      'title': 'Incorporate env key from kernelspecs'},
#     {'createdAt': '2017-04-24T13:36:27Z',
#      'number': 22,
#      'title': 'An in-range update of mocha is breaking the build 🚨'},
#     {'createdAt': '2017-05-07T13:38:45Z',
#      'number': 24,
#      'title': "CRITICAL: change the default spawn options to include `stdio = 'ignore'`"}]},
#   'name': 'spawnteract'},
#  {'issues': {'nodes': [{'createdAt': '2017-01-10T21:48:08Z',
#      'number': 11,
#      'title': 'A possible dashboard, for nteract, desktop and exportable to web'},
#     {'createdAt': '2017-01-17T21:14:04Z',
#      'number': 12,
#      'title': 'Establish a Design Guide'},
#     {'createdAt': '2017-04-06T04:38:49Z',
#      'number': 15,
#      'title': 'Touch-interface friendly'},
#     {'createdAt': '2017-04-06T21:40:51Z',
#      'number': 16,
#      'title': 'Creator UX improvement proposal'}]},
#   'name': 'design'},
#  {'issues': {'nodes': []}, 'name': 'specs'},
#  {'issues': {'nodes': []}, 'name': 'kernel-relay'},
#  {'issues': {'nodes': [{'createdAt': '2016-05-14T23:12:35Z',
#      'number': 4,
#      'title': 'Switch to CommonJS RxJS, bump to 5.0.0-beta.6'},
#     {'createdAt': '2016-06-12T02:05:18Z',
#      'number': 6,
#      'title': 'Add JSDoc comments to src/index.js'}]},
#   'name': 'enchannel-socketio-backend'},
#  {'issues': {'nodes': [{'createdAt': '2016-08-22T01:47:50Z',
#      'number': 16,
#      'title': 'Review commutable tutorial for accessibility'},
#     {'createdAt': '2016-08-22T18:55:03Z',
#      'number': 17,
#      'title': 'Typo in docs'},
#     {'createdAt': '2016-10-29T15:26:13Z',
#      'number': 19,
#      'title': 'Test commutable instructions'}]},
#   'name': 'docs'},
#  {'issues': {'nodes': [{'createdAt': '2016-04-20T13:51:25Z',
#      'number': 2,
#      'title': 'Alternative logo proposal'},
#     {'createdAt': '2016-06-07T04:12:59Z',
#      'number': 5,
#      'title': 'Svg media queries'},
#     {'createdAt': '2016-07-22T18:49:12Z',
#      'number': 6,
#      'title': 'Create favicon.ico'},
#     {'createdAt': '2017-10-30T19:44:19Z',
#      'number': 12,
#      'title': 'Create a version of the logo that looks good enclosed in a circle'}]},
#   'name': 'logos'},
#  {'issues': {'nodes': []}, 'name': 'enchannel-in-memory'},
#  {'issues': {'nodes': [{'createdAt': '2016-05-14T23:11:48Z',
#      'number': 2,
#      'title': 'Follow suit with enchannel-zmq-backend'},
#     {'createdAt': '2016-05-22T04:49:01Z',
#      'number': 4,
#      'title': 'Adapt to Rx DOM'}]},
#   'name': 'enchannel-notebook-backend'},
#  {'issues': {'nodes': [{'createdAt': '2016-03-29T19:01:13Z',
#      'number': 2,
#      'title': 'Handle more escape codes'},
#     {'createdAt': '2016-04-09T00:16:15Z',
#      'number': 3,
#      'title': 'Specify the React peer dependency'},
#     {'createdAt': '2016-04-09T01:07:01Z',
#      'number': 5,
#      'title': 'W U no tests ?'},
#     {'createdAt': '2016-05-02T01:25:48Z',
#      'number': 7,
#      'title': 'Consider transpiling'}]},
#   'name': 'ansi-to-react'},
#  {'issues': {'nodes': []}, 'name': 'transformime-marked'},
#  {'issues': {'nodes': [{'createdAt': '2016-07-05T00:52:44Z',
#      'number': 4,
#      'title': 'Add example to readme'},
#     {'createdAt': '2016-08-24T20:20:59Z',
#      'number': 11,
#      'title': 'Missing mathchoice(?)'},
#     {'createdAt': '2016-08-25T00:06:01Z',
#      'number': 13,
#      'title': 'Investigate which tex extensions are missing'},
#     {'createdAt': '2016-09-03T00:29:21Z',
#      'number': 15,
#      'title': 'Required sourcemap?'}]},
#   'name': 'mathjax-electron'},
#  {'issues': {'nodes': [{'createdAt': '2016-04-14T18:53:16Z',
#      'number': 1,
#      'title': 'Include Source Code Pro and Source Sans Pro'}]},
#   'name': 'assets'},
#  {'issues': {'nodes': []}, 'name': 'associator'},
#  {'issues': {'nodes': [{'createdAt': '2016-05-05T14:12:40Z',
#      'number': 7,
#      'title': 'Setup Travis'},
#     {'createdAt': '2016-06-10T17:30:24Z',
#      'number': 11,
#      'title': 'Autoconvert old notebooks to latest'},
#     {'createdAt': '2017-03-15T19:30:20Z',
#      'number': 19,
#      'title': 'Redirect users to @nteract/notebook-preview'},
#     {'createdAt': '2017-10-17T20:13:50Z',
#      'number': 20,
#      'title': 'Rendering Performance Issues'}]},
#   'name': 'notebook-preview'},
#  {'issues': {'nodes': []}, 'name': 'naming'},
#  {'issues': {'nodes': [{'createdAt': '2017-03-14T13:31:16Z',
#      'number': 6,
#      'title': 'Ideas to real-time data analysis'}]},
#   'name': 'initiatives'},
#  {'issues': {'nodes': [{'createdAt': '2016-09-04T20:43:28Z',
#      'number': 1,
#      'title': 'Test on windows and linux'},
#     {'createdAt': '2017-03-15T07:56:40Z',
#      'number': 15,
#      'title': "Opening terminal in Windows with a folder doesn't change the drive"},
#     {'createdAt': '2017-03-15T08:20:56Z',
#      'number': 16,
#      'title': 'Opening a Linux terminal with folder with spaces fails'}]},
#   'name': 'term-launcher'},
#  {'issues': {'nodes': []}, 'name': 'meeting-minutes'},
#  {'issues': {'nodes': [{'createdAt': '2016-10-06T10:30:14Z',
#      'number': 1,
#      'title': 'Also test with electron'}]},
#   'name': 'zmq-prebuilt-testing'},
#  {'issues': {'nodes': []}, 'name': 'oauth-server'},
#  {'issues': {'nodes': [{'createdAt': '2017-03-04T23:09:10Z',
#      'number': 2,
#      'title': 'Create a kernels page'},
#     {'createdAt': '2017-03-17T17:47:12Z',
#      'number': 8,
#      'title': 'Prefetch over http for https version.'},
#     {'createdAt': '2017-04-28T21:20:08Z',
#      'number': 13,
#      'title': 'Include Scala on /kernels page'},
#     {'createdAt': '2017-04-29T01:34:11Z',
#      'number': 14,
#      'title': 'Include Julia on the /kernels page'}]},
#   'name': 'nteract.io'},
#  {'issues': {'nodes': [{'createdAt': '2017-01-27T11:09:36Z',
#      'number': 4,
#      'title': 'An in-range update of should is breaking the build 🚨'},
#     {'createdAt': '2017-04-05T22:41:06Z',
#      'number': 5,
#      'title': 'An in-range update of nan is breaking the build 🚨'},
#     {'createdAt': '2017-05-24T20:26:29Z',
#      'number': 6,
#      'title': 'An in-range update of mocha is breaking the build 🚨'},
#     {'createdAt': '2017-07-24T17:33:57Z',
#      'number': 7,
#      'title': 'An in-range update of semver is breaking the build 🚨'}]},
#   'name': 'zmq-static'},
#  {'issues': {'nodes': []}, 'name': 'inodejs'},
#  {'issues': {'nodes': []}, 'name': 'tick-tock'},
#  {'issues': {'nodes': [{'createdAt': '2016-10-18T00:19:09Z',
#      'number': 12,
#      'title': 'Sessions API'},
#     {'createdAt': '2016-10-22T18:10:38Z',
#      'number': 15,
#      'title': 'Handle Authentication'},
#     {'createdAt': '2016-10-22T19:02:14Z',
#      'number': 17,
#      'title': 'Include idiomatic example usage in the README'},
#     {'createdAt': '2016-11-06T21:32:49Z',
#      'number': 26,
#      'title': 'Contents API Checklist'}]},
#   'name': 'rx-jupyter'},
#  {'issues': {'nodes': [{'createdAt': '2017-05-31T08:40:35Z',
#      'number': 2,
#      'title': 'libraries 4.2.0-x64 miss TweetNacl'}]},
#   'name': 'libzmq-win'},
#  {'issues': {'nodes': [{'createdAt': '2016-11-09T18:47:28Z',
#      'number': 3,
#      'title': 'Create perf measuring scripts with commutable'}]},
#   'name': 'commutable-perf'},
#  {'issues': {'nodes': []}, 'name': 'plotly.js'},
#  {'issues': {'nodes': []}, 'name': 'vega'},
#  {'issues': {'nodes': [{'createdAt': '2017-01-25T02:59:19Z',
#      'number': 8,
#      'title': 'Support auth via aws_access_key_id & aws_secret_access_key '},
#     {'createdAt': '2017-01-25T03:04:00Z',
#      'number': 9,
#      'title': 'Persist notebooks back to S3'},
#     {'createdAt': '2017-01-26T21:43:40Z',
#      'number': 13,
#      'title': 'Add tests for react components '},
#     {'createdAt': '2017-01-31T23:51:02Z',
#      'number': 19,
#      'title': 'commuter  screen shots'}]},
#   'name': 'commuter'},
#  {'issues': {'nodes': [{'createdAt': '2017-01-10T21:24:08Z',
#      'number': 2,
#      'title': 'Additional resources'},
#     {'createdAt': '2017-01-10T21:32:50Z',
#      'number': 3,
#      'title': 'Integrating with nteract build'},
#     {'createdAt': '2017-01-10T21:37:00Z',
#      'number': 4,
#      'title': 'Where to build?'},
#     {'createdAt': '2017-01-10T21:59:00Z',
#      'number': 6,
#      'title': 'Where to store assets'}]},
#   'name': 'snakestagram'},
#  {'issues': {'nodes': []}, 'name': 'commutable-models'},
#  {'issues': {'nodes': [{'createdAt': '2017-05-04T13:42:38Z',
#      'number': 4,
#      'title': 'Reduce size even further'}]},
#   'name': 'minimal-plotly'},
#  {'issues': {'nodes': [{'createdAt': '2017-06-02T16:32:15Z',
#      'number': 1,
#      'title': 'Add a link to the rendered book in README'}]},
#   'name': 'desktop-manual'},
#  {'issues': {'nodes': [{'createdAt': '2017-07-06T20:47:53Z',
#      'number': 2,
#      'title': 'Dask (or threadpool) friendly functions'},
#     {'createdAt': '2017-07-10T22:57:59Z',
#      'number': 4,
#      'title': 'execute module is missing'},
#     {'createdAt': '2017-07-10T23:18:25Z',
#      'number': 7,
#      'title': 'setup tox for testing locally'},
#     {'createdAt': '2017-08-09T11:16:39Z',
#      'number': 20,
#      'title': 'Is it possible to run with Jupyter Notebook (web env)?'}]},
#   'name': 'papermill'},
#  {'issues': {'nodes': []}, 'name': 'cabinet'},
#  {'issues': {'nodes': []}, 'name': 'papermillr'},
#  {'issues': {'nodes': [{'createdAt': '2017-09-19T21:01:01Z',
#      'number': 3,
#      'title': 'Write JSON Schema for the VDOM Spec'},
#     {'createdAt': '2017-09-19T21:03:07Z',
#      'number': 4,
#      'title': 'Create example notebooks'},
#     {'createdAt': '2017-09-22T21:05:40Z',
#      'number': 7,
#      'title': 'Check out JSON Markup Language'},
#     {'createdAt': '2017-09-25T18:45:41Z',
#      'number': 11,
#      'title': 'Write some best practices guidance for creating components'}]},
#   'name': 'vdom'}]

# %%
headers = ['name', 'issues']

rows = []
for obj in unpacked:
    issue_list = []
    for item in obj['issues']['nodes']:
        issue_list.append({item['number'], item['title'], item['createdAt']})
    new_dict = {'name':obj['name'], 'issues':issue_list}
    rows.append(new_dict)
rows
# Out:
# [{'issues': [{1, '2015-05-17T14:09:54Z', 'Handle input on stdin'},
#    {2, '2015-06-16T14:01:14Z', 'Installation Problems'},
#    {'2015-06-17T15:15:09Z', 6, 'Cannot build on Windows'},
#    {'2015-06-26T03:12:54Z',
#     8,
#     'Display area is launched for kernels that no longer exist'}],
#   'name': 'sidecar'},
#  {'issues': [{1, '2015-05-18T03:34:11Z', 'Awesome'},
#    {2, '2015-05-18T04:17:49Z', 'Integrate with autocomplete plus'},
#    {'2015-05-18T04:20:26Z', 3, 'Plots are a bit constrained'},
#    {'2015-05-18T13:26:34Z',
#     5,
#     "Uncaught TypeError: Cannot read property 'toLowerCase' of undefined"}],
#   'name': 'hydrogen'},
#  {'issues': [{1, '2015-06-16T01:29:51Z', 'Expose higher level interfaces'},
#    {2, '2015-06-18T22:37:14Z', 'support ipython 2/3'},
#    {'2015-08-31T11:40:05Z', 4, 'Use the implementation in Hydrogen'},
#    {'2016-01-07T07:15:05Z', 5, 'Implement Jupyter Paths directly'}],
#   'name': 'jupyter-paths'},
#  {'issues': [{1, '2015-12-24T06:00:59Z', 'zmq for everyone'},
#    {2, '2015-12-24T06:06:13Z', 'Scope/Roadmap'},
#    {'2016-01-01T16:14:29Z', 3, 'Notebook operations'},
#    {'2016-01-01T16:15:41Z', 4, 'Kernelspec operations'}],
#   'name': 'nteract'},
#  {'issues': [{'2016-06-08T02:56:55Z',
#     5,
#     'Resources not loaded properly when refreshing after scrolling'},
#    {'2016-06-08T02:57:39Z',
#     6,
#     'Download buttons should emphasize that it is alpha software'},
#    {11, '2016-06-14T18:37:02Z', 'What language does it support?'},
#    {14, '2016-08-11T15:41:55Z', "Hero banner buttons don't work on mobile"}],
#   'name': 'nteract.github.io'},
#  {'issues': [{12, '2015-07-11T17:56:18Z', 'Live reload for development'},
#    {17, '2015-07-14T03:05:03Z', 'Jupyter migration (meta issue)'},
#    {18, '2015-07-14T03:38:04Z', 'Include fetch polyfill in demo'},
#    {20,
#     '2015-07-22T22:57:21Z',
#     "Cannot read property 'ownerDocument' of null"}],
#   'name': 'jupyter-display-area'},
#  {'issues': [{'1.0.0 release', 17, '2015-07-21T00:07:45Z'},
#    {19, '2015-07-23T17:05:23Z', 'Renderer -> Transformer'},
#    {'2015-07-26T17:39:02Z',
#     27,
#     'HTML mimetype should execute script, or provide the option to do so.'},
#    {'2015-08-01T14:22:25Z',
#     29,
#     'Adapt tests to work across karma multi-browser runs'}],
#   'name': 'transformime'},
#  {'issues': [{2,
#     '2015-07-24T17:25:18Z',
#     'Mimetypes to render to conform with notebook'}],
#   'name': 'transformime-jupyter-transformers'},
#  {'issues': [], 'name': 'transformime-commonmark'},
#  {'issues': [], 'name': 'jupyter-session'},
#  {'issues': [], 'name': 'jupyter-kernel-launcher'},
#  {'issues': [], 'name': 'jupyter-transport-wrapper'},
#  {'issues': [{2, '2016-01-20T17:45:50Z', 'Provide the runtime directory'}],
#   'name': 'ipython-paths'},
#  {'issues': [{1, '2016-01-03T07:50:49Z', 'Jupyter mimetypes'},
#    {'2016-03-13T08:30:08Z', 9, 'text/plain should interpret ANSI'},
#    {17,
#     '2016-08-21T22:41:29Z',
#     'Switch our Latex Transform to using mathjax-electron'},
#    {18, '2016-08-23T22:10:08Z', 'Move this package into nteract/nteract'}],
#   'name': 'transformime-react'},
#  {'issues': [{1, '2016-01-08T14:57:08Z', "What's in a name?"},
#    {2, '2016-01-08T16:41:36Z', 'Different models and different users'},
#    {'2016-01-16T17:55:09Z', 6, 'Rely on notebook-test-data'},
#    {'2016-01-19T04:14:20Z', 8, 'Notebook format conversion'}],
#   'name': 'commutable'},
#  {'issues': [{1,
#     '2016-01-10T04:49:47Z',
#     'ConsoleText should create React Components'},
#    {2, '2016-01-19T04:36:17Z', 'Write up example usage'},
#    {'2016-01-19T04:38:51Z', 3, 'Transforms should be a prop'},
#    {'2016-02-17T23:30:54Z', 6, 'Create an IFramed HTML output element'}],
#   'name': 'react-jupyter-display-area'},
#  {'issues': [{1, '2016-01-12T07:03:46Z', 'Interface iterations'},
#    {'2016-01-13T05:10:17Z', 4, 'Add note about zmq installation'},
#    {11, '2016-01-19T18:17:31Z', 'Switch to RxJS 5'},
#    {15, '2016-02-12T04:24:26Z', 'Bump to RxJS 5.0 beta 2'}],
#   'name': 'enchannel-zmq-backend'},
#  {'issues': [{1, '2016-01-13T01:14:29Z', 'Outline what this is about'},
#    {'2016-01-13T18:37:23Z', 3, 'Object.freeze() messages'},
#    {'2016-01-13T19:15:15Z', 4, 'Export 5 functions instead of 1'},
#    {'2016-02-29T18:14:15Z',
#     6,
#     'Should there be a spec for starting/stopping a kernel'}],
#   'name': 'enchannel'},
#  {'issues': [{'2016-05-05T15:42:43Z', 3, 'Bring in nice, useful notebooks'}],
#   'name': 'notebook-test-data'},
#  {'issues': [{'2016-01-22T06:28:07Z',
#     3,
#     'Clean up connection file, connection'},
#    {'2016-01-22T06:29:37Z', 4, 'In[ ] and Out[ ]'},
#    {'2016-01-22T06:30:37Z', 5, 'Completion'},
#    {'2016-01-22T06:37:05Z', 6, 'Wonky prompt display'}],
#   'name': 'ick'},
#  {'issues': [{1, '2016-01-19T03:25:41Z', 'Detect Running Kernels'},
#    {'2016-01-19T03:35:24Z', 3, 'Style output more appropriately'},
#    {'2016-01-19T04:44:20Z', 4, 'Detect iterm2 and display image directly'}],
#   'name': 'terminal-sidecar'},
#  {'issues': [{14,
#     '2016-02-03T03:07:59Z',
#     'Problem: Object response is not jupyter kernelspec format'},
#    {18,
#     '2016-05-21T11:59:22Z',
#     "Kernelspecs doesn't find python kernel from sys-dir"},
#    {'2017-04-24T13:29:39Z',
#     23,
#     'An in-range update of mocha is breaking the build 🚨'},
#    {'2017-05-16T22:48:38Z', 24, 'The title of this repo has a typo in it!'}],
#   'name': 'kernelspecs'},
#  {'issues': [{1,
#     '2016-01-23T01:48:28Z',
#     'Rely on node-temp for cleaning up kernel files?'},
#    {14, '2016-08-16T04:50:54Z', 'Incorporate env key from kernelspecs'},
#    {'2017-04-24T13:36:27Z',
#     22,
#     'An in-range update of mocha is breaking the build 🚨'},
#    {'2017-05-07T13:38:45Z',
#     24,
#     "CRITICAL: change the default spawn options to include `stdio = 'ignore'`"}],
#   'name': 'spawnteract'},
#  {'issues': [{11,
#     '2017-01-10T21:48:08Z',
#     'A possible dashboard, for nteract, desktop and exportable to web'},
#    {12, '2017-01-17T21:14:04Z', 'Establish a Design Guide'},
#    {15, '2017-04-06T04:38:49Z', 'Touch-interface friendly'},
#    {16, '2017-04-06T21:40:51Z', 'Creator UX improvement proposal'}],
#   'name': 'design'},
#  {'issues': [], 'name': 'specs'},
#  {'issues': [], 'name': 'kernel-relay'},
#  {'issues': [{'2016-05-14T23:12:35Z',
#     4,
#     'Switch to CommonJS RxJS, bump to 5.0.0-beta.6'},
#    {'2016-06-12T02:05:18Z', 6, 'Add JSDoc comments to src/index.js'}],
#   'name': 'enchannel-socketio-backend'},
#  {'issues': [{16,
#     '2016-08-22T01:47:50Z',
#     'Review commutable tutorial for accessibility'},
#    {17, '2016-08-22T18:55:03Z', 'Typo in docs'},
#    {19, '2016-10-29T15:26:13Z', 'Test commutable instructions'}],
#   'name': 'docs'},
#  {'issues': [{2, '2016-04-20T13:51:25Z', 'Alternative logo proposal'},
#    {'2016-06-07T04:12:59Z', 5, 'Svg media queries'},
#    {'2016-07-22T18:49:12Z', 6, 'Create favicon.ico'},
#    {12,
#     '2017-10-30T19:44:19Z',
#     'Create a version of the logo that looks good enclosed in a circle'}],
#   'name': 'logos'},
#  {'issues': [], 'name': 'enchannel-in-memory'},
#  {'issues': [{2,
#     '2016-05-14T23:11:48Z',
#     'Follow suit with enchannel-zmq-backend'},
#    {'2016-05-22T04:49:01Z', 4, 'Adapt to Rx DOM'}],
#   'name': 'enchannel-notebook-backend'},
#  {'issues': [{2, '2016-03-29T19:01:13Z', 'Handle more escape codes'},
#    {'2016-04-09T00:16:15Z', 3, 'Specify the React peer dependency'},
#    {'2016-04-09T01:07:01Z', 5, 'W U no tests ?'},
#    {'2016-05-02T01:25:48Z', 7, 'Consider transpiling'}],
#   'name': 'ansi-to-react'},
#  {'issues': [], 'name': 'transformime-marked'},
#  {'issues': [{'2016-07-05T00:52:44Z', 4, 'Add example to readme'},
#    {11, '2016-08-24T20:20:59Z', 'Missing mathchoice(?)'},
#    {13,
#     '2016-08-25T00:06:01Z',
#     'Investigate which tex extensions are missing'},
#    {15, '2016-09-03T00:29:21Z', 'Required sourcemap?'}],
#   'name': 'mathjax-electron'},
#  {'issues': [{1,
#     '2016-04-14T18:53:16Z',
#     'Include Source Code Pro and Source Sans Pro'}],
#   'name': 'assets'},
#  {'issues': [], 'name': 'associator'},
#  {'issues': [{'2016-05-05T14:12:40Z', 7, 'Setup Travis'},
#    {11, '2016-06-10T17:30:24Z', 'Autoconvert old notebooks to latest'},
#    {19, '2017-03-15T19:30:20Z', 'Redirect users to @nteract/notebook-preview'},
#    {20, '2017-10-17T20:13:50Z', 'Rendering Performance Issues'}],
#   'name': 'notebook-preview'},
#  {'issues': [], 'name': 'naming'},
#  {'issues': [{'2017-03-14T13:31:16Z', 6, 'Ideas to real-time data analysis'}],
#   'name': 'initiatives'},
#  {'issues': [{1, '2016-09-04T20:43:28Z', 'Test on windows and linux'},
#    {15,
#     '2017-03-15T07:56:40Z',
#     "Opening terminal in Windows with a folder doesn't change the drive"},
#    {16,
#     '2017-03-15T08:20:56Z',
#     'Opening a Linux terminal with folder with spaces fails'}],
#   'name': 'term-launcher'},
#  {'issues': [], 'name': 'meeting-minutes'},
#  {'issues': [{1, '2016-10-06T10:30:14Z', 'Also test with electron'}],
#   'name': 'zmq-prebuilt-testing'},
#  {'issues': [], 'name': 'oauth-server'},
#  {'issues': [{2, '2017-03-04T23:09:10Z', 'Create a kernels page'},
#    {'2017-03-17T17:47:12Z', 8, 'Prefetch over http for https version.'},
#    {13, '2017-04-28T21:20:08Z', 'Include Scala on /kernels page'},
#    {14, '2017-04-29T01:34:11Z', 'Include Julia on the /kernels page'}],
#   'name': 'nteract.io'},
#  {'issues': [{'2017-01-27T11:09:36Z',
#     4,
#     'An in-range update of should is breaking the build 🚨'},
#    {'2017-04-05T22:41:06Z',
#     5,
#     'An in-range update of nan is breaking the build 🚨'},
#    {'2017-05-24T20:26:29Z',
#     6,
#     'An in-range update of mocha is breaking the build 🚨'},
#    {'2017-07-24T17:33:57Z',
#     7,
#     'An in-range update of semver is breaking the build 🚨'}],
#   'name': 'zmq-static'},
#  {'issues': [], 'name': 'inodejs'},
#  {'issues': [], 'name': 'tick-tock'},
#  {'issues': [{12, '2016-10-18T00:19:09Z', 'Sessions API'},
#    {15, '2016-10-22T18:10:38Z', 'Handle Authentication'},
#    {17,
#     '2016-10-22T19:02:14Z',
#     'Include idiomatic example usage in the README'},
#    {'2016-11-06T21:32:49Z', 26, 'Contents API Checklist'}],
#   'name': 'rx-jupyter'},
#  {'issues': [{2,
#     '2017-05-31T08:40:35Z',
#     'libraries 4.2.0-x64 miss TweetNacl'}],
#   'name': 'libzmq-win'},
#  {'issues': [{'2016-11-09T18:47:28Z',
#     3,
#     'Create perf measuring scripts with commutable'}],
#   'name': 'commutable-perf'},
#  {'issues': [], 'name': 'plotly.js'},
#  {'issues': [], 'name': 'vega'},
#  {'issues': [{'2017-01-25T02:59:19Z',
#     8,
#     'Support auth via aws_access_key_id & aws_secret_access_key '},
#    {'2017-01-25T03:04:00Z', 9, 'Persist notebooks back to S3'},
#    {13, '2017-01-26T21:43:40Z', 'Add tests for react components '},
#    {19, '2017-01-31T23:51:02Z', 'commuter  screen shots'}],
#   'name': 'commuter'},
#  {'issues': [{2, '2017-01-10T21:24:08Z', 'Additional resources'},
#    {'2017-01-10T21:32:50Z', 3, 'Integrating with nteract build'},
#    {'2017-01-10T21:37:00Z', 4, 'Where to build?'},
#    {'2017-01-10T21:59:00Z', 6, 'Where to store assets'}],
#   'name': 'snakestagram'},
#  {'issues': [], 'name': 'commutable-models'},
#  {'issues': [{'2017-05-04T13:42:38Z', 4, 'Reduce size even further'}],
#   'name': 'minimal-plotly'},
#  {'issues': [{1,
#     '2017-06-02T16:32:15Z',
#     'Add a link to the rendered book in README'}],
#   'name': 'desktop-manual'},
#  {'issues': [{2,
#     '2017-07-06T20:47:53Z',
#     'Dask (or threadpool) friendly functions'},
#    {'2017-07-10T22:57:59Z', 4, 'execute module is missing'},
#    {'2017-07-10T23:18:25Z', 7, 'setup tox for testing locally'},
#    {20,
#     '2017-08-09T11:16:39Z',
#     'Is it possible to run with Jupyter Notebook (web env)?'}],
#   'name': 'papermill'},
#  {'issues': [], 'name': 'cabinet'},
#  {'issues': [], 'name': 'papermillr'},
#  {'issues': [{'2017-09-19T21:01:01Z',
#     3,
#     'Write JSON Schema for the VDOM Spec'},
#    {'2017-09-19T21:03:07Z', 4, 'Create example notebooks'},
#    {'2017-09-22T21:05:40Z', 7, 'Check out JSON Markup Language'},
#    {11,
#     '2017-09-25T18:45:41Z',
#     'Write some best practices guidance for creating components'}],
#   'name': 'vdom'}]

# %%
with open('mydata.csv', 'w') as f:
    f_csv = csv.DictWriter(f, headers)
    f_csv.writeheader()
    f_csv.writerows(rows)

# %% [markdown]
# Check file

# %%
# %%bash
#
# less mydata.csv
# Out:
# name,issues
# sidecar,"[{1, '2015-05-17T14:09:54Z', 'Handle input on stdin'}, {'2015-06-16T14:01:14Z', 2, 'Installation Problems'}, {'Cannot build on Windows', '2015-06-17T15:15:09Z', 6}, {8, 'Display area is launched for kernels that no longer exist', '2015-06-26T03:12:54Z'}]"
# hydrogen,"[{1, '2015-05-18T03:34:11Z', 'Awesome'}, {'2015-05-18T04:17:49Z', 2, 'Integrate with autocomplete plus'}, {3, '2015-05-18T04:20:26Z', 'Plots are a bit constrained'}, {""Uncaught TypeError: Cannot read property 'toLowerCase' of undefined"", 5, '2015-05-18T13:26:34Z'}]"
# jupyter-paths,"[{1, '2015-06-16T01:29:51Z', 'Expose higher level interfaces'}, {2, '2015-06-18T22:37:14Z', 'support ipython 2/3'}, {'Use the implementation in Hydrogen', 4, '2015-08-31T11:40:05Z'}, {'Implement Jupyter Paths directly', '2016-01-07T07:15:05Z', 5}]"
# nteract,"[{'2015-12-24T06:00:59Z', 1, 'zmq for everyone'}, {'2015-12-24T06:06:13Z', 2, 'Scope/Roadmap'}, {'Notebook operations', '2016-01-01T16:14:29Z', 3}, {'Kernelspec operations', 4, '2016-01-01T16:15:41Z'}]"
# nteract.github.io,"[{'2016-06-08T02:56:55Z', 'Resources not loaded properly when refreshing after scrolling', 5}, {'Download buttons should emphasize that it is alpha software', 6, '2016-06-08T02:57:39Z'}, {'2016-06-14T18:37:02Z', 11, 'What language does it support?'}, {'2016-08-11T15:41:55Z', ""Hero banner buttons don't work on mobile"", 14}]"
# jupyter-display-area,"[{'2015-07-11T17:56:18Z', 12, 'Live reload for development'}, {'2015-07-14T03:05:03Z', 17, 'Jupyter migration (meta issue)'}, {18, '2015-07-14T03:38:04Z', 'Include fetch polyfill in demo'}, {'2015-07-22T22:57:21Z', 20, ""Cannot read property 'ownerDocument' of null""}]"
# transformime,"[{'2015-07-21T00:07:45Z', 17, '1.0.0 release'}, {19, 'Renderer -> Transformer', '2015-07-23T17:05:23Z'}, {'2015-07-26T17:39:02Z', 27, 'HTML mimetype should execute script, or provide the option to do so.'}, {'Adapt tests to work across karma multi-browser runs', 29, '2015-08-01T14:22:25Z'}]"
# transformime-jupyter-transformers,"[{'Mimetypes to render to conform with notebook', 2, '2015-07-24T17:25:18Z'}]"
# transformime-commonmark,[]
# jupyter-session,[]
# jupyter-kernel-launcher,[]
# jupyter-transport-wrapper,[]
# ipython-paths,"[{2, '2016-01-20T17:45:50Z', 'Provide the runtime directory'}]"
# transformime-react,"[{1, 'Jupyter mimetypes', '2016-01-03T07:50:49Z'}, {9, '2016-03-13T08:30:08Z', 'text/plain should interpret ANSI'}, {17, 'Switch our Latex Transform to using mathjax-electron', '2016-08-21T22:41:29Z'}, {'Move this package into nteract/nteract', 18, '2016-08-23T22:10:08Z'}]"
# commutable,"[{1, '2016-01-08T14:57:08Z', ""What's in a name?""}, {'2016-01-08T16:41:36Z', 2, 'Different models and different users'}, {'2016-01-16T17:55:09Z', 'Rely on notebook-test-data', 6}, {8, '2016-01-19T04:14:20Z', 'Notebook format conversion'}]"
# react-jupyter-display-area,"[{1, '2016-01-10T04:49:47Z', 'ConsoleText should create React Components'}, {2, '2016-01-19T04:36:17Z', 'Write up example usage'}, {'Transforms should be a prop', 3, '2016-01-19T04:38:51Z'}, {'Create an IFramed HTML output element', '2016-02-17T23:30:54Z', 6}]"
# enchannel-zmq-backend,"[{1, '2016-01-12T07:03:46Z', 'Interface iterations'}, {'Add note about zmq installation', '2016-01-13T05:10:17Z', 4}, {'Switch to RxJS 5', 11, '2016-01-19T18:17:31Z'}, {'Bump to RxJS 5.0 beta 2', '2016-02-12T04:24:26Z', 15}]"
# enchannel,"[{1, '2016-01-13T01:14:29Z', 'Outline what this is about'}, {'2016-01-13T18:37:23Z', 3, 'Object.freeze() messages'}, {'Export 5 functions instead of 1', 4, '2016-01-13T19:15:15Z'}, {'2016-02-29T18:14:15Z', 6, 'Should there be a spec for starting/stopping a kernel'}]"
# notebook-test-data,"[{'2016-05-05T15:42:43Z', 'Bring in nice, useful notebooks', 3}]"
# ick,"[{3, '2016-01-22T06:28:07Z', 'Clean up connection file, connection'}, {'In[ ] and Out[ ]', 4, '2016-01-22T06:29:37Z'}, {'Completion', '2016-01-22T06:30:37Z', 5}, {'2016-01-22T06:37:05Z', 'Wonky prompt display', 6}]"
# terminal-sidecar,"[{1, '2016-01-19T03:25:41Z', 'Detect Running Kernels'}, {'Style output more appropriately', 3, '2016-01-19T03:35:24Z'}, {'Detect iterm2 and display image directly', 4, '2016-01-19T04:44:20Z'}]"
# kernelspecs,"[{'Problem: Object response is not jupyter kernelspec format', '2016-02-03T03:07:59Z', 14}, {""Kernelspecs doesn't find python kernel from sys-dir"", 18, '2016-05-21T11:59:22Z'}, {'An in-range update of mocha is breaking the build 🚨', '2017-04-24T13:29:39Z', 23}, {24, 'The title of this repo has a typo in it!', '2017-05-16T22:48:38Z'}]"
# spawnteract,"[{1, 'Rely on node-temp for cleaning up kernel files?', '2016-01-23T01:48:28Z'}, {'Incorporate env key from kernelspecs', 14, '2016-08-16T04:50:54Z'}, {'An in-range update of mocha is breaking the build 🚨', '2017-04-24T13:36:27Z', 22}, {24, '2017-05-07T13:38:45Z', ""CRITICAL: change the default spawn options to include `stdio = 'ignore'`""}]"
# design,"[{'2017-01-10T21:48:08Z', 11, 'A possible dashboard, for nteract, desktop and exportable to web'}, {'Establish a Design Guide', '2017-01-17T21:14:04Z', 12}, {'2017-04-06T04:38:49Z', 'Touch-interface friendly', 15}, {16, '2017-04-06T21:40:51Z', 'Creator UX improvement proposal'}]"
# specs,[]
# kernel-relay,[]
# enchannel-socketio-backend,"[{'Switch to CommonJS RxJS, bump to 5.0.0-beta.6', 4, '2016-05-14T23:12:35Z'}, {'2016-06-12T02:05:18Z', 6, 'Add JSDoc comments to src/index.js'}]"
# docs,"[{16, 'Review commutable tutorial for accessibility', '2016-08-22T01:47:50Z'}, {17, '2016-08-22T18:55:03Z', 'Typo in docs'}, {'Test commutable instructions', '2016-10-29T15:26:13Z', 19}]"
# logos,"[{2, 'Alternative logo proposal', '2016-04-20T13:51:25Z'}, {'2016-06-07T04:12:59Z', 'Svg media queries', 5}, {'Create favicon.ico', '2016-07-22T18:49:12Z', 6}, {'Create a version of the logo that looks good enclosed in a circle', '2017-10-30T19:44:19Z', 12}]"
# enchannel-in-memory,[]
# enchannel-notebook-backend,"[{'Follow suit with enchannel-zmq-backend', 2, '2016-05-14T23:11:48Z'}, {4, '2016-05-22T04:49:01Z', 'Adapt to Rx DOM'}]"
# ansi-to-react,"[{2, '2016-03-29T19:01:13Z', 'Handle more escape codes'}, {'Specify the React peer dependency', 3, '2016-04-09T00:16:15Z'}, {'W U no tests ?', '2016-04-09T01:07:01Z', 5}, {'2016-05-02T01:25:48Z', 'Consider transpiling', 7}]"
# transformime-marked,[]
# mathjax-electron,"[{'2016-07-05T00:52:44Z', 4, 'Add example to readme'}, {'2016-08-24T20:20:59Z', 'Missing mathchoice(?)', 11}, {'Investigate which tex extensions are missing', '2016-08-25T00:06:01Z', 13}, {'Required sourcemap?', '2016-09-03T00:29:21Z', 15}]"
# assets,"[{1, '2016-04-14T18:53:16Z', 'Include Source Code Pro and Source Sans Pro'}]"
# associator,[]
# notebook-preview,"[{'2016-05-05T14:12:40Z', 'Setup Travis', 7}, {'Autoconvert old notebooks to latest', 11, '2016-06-10T17:30:24Z'}, {19, '2017-03-15T19:30:20Z', 'Redirect users to @nteract/notebook-preview'}, {'Rendering Performance Issues', '2017-10-17T20:13:50Z', 20}]"
# naming,[]
# initiatives,"[{'Ideas to real-time data analysis', '2017-03-14T13:31:16Z', 6}]"
# term-launcher,"[{'Test on windows and linux', 1, '2016-09-04T20:43:28Z'}, {'2017-03-15T07:56:40Z', ""Opening terminal in Windows with a folder doesn't change the drive"", 15}, {16, 'Opening a Linux terminal with folder with spaces fails', '2017-03-15T08:20:56Z'}]"
# meeting-minutes,[]
# zmq-prebuilt-testing,"[{1, 'Also test with electron', '2016-10-06T10:30:14Z'}]"
# oauth-server,[]
# nteract.io,"[{'Create a kernels page', 2, '2017-03-04T23:09:10Z'}, {8, 'Prefetch over http for https version.', '2017-03-17T17:47:12Z'}, {'2017-04-28T21:20:08Z', 13, 'Include Scala on /kernels page'}, {'2017-04-29T01:34:11Z', 'Include Julia on the /kernels page', 14}]"
# zmq-static,"[{'2017-01-27T11:09:36Z', 4, 'An in-range update of should is breaking the build 🚨'}, {'2017-04-05T22:41:06Z', 'An in-range update of nan is breaking the build 🚨', 5}, {'An in-range update of mocha is breaking the build 🚨', 6, '2017-05-24T20:26:29Z'}, {'2017-07-24T17:33:57Z', 'An in-range update of semver is breaking the build 🚨', 7}]"
# inodejs,[]
# tick-tock,[]
# rx-jupyter,"[{'Sessions API', 12, '2016-10-18T00:19:09Z'}, {'2016-10-22T18:10:38Z', 'Handle Authentication', 15}, {'Include idiomatic example usage in the README', 17, '2016-10-22T19:02:14Z'}, {'2016-11-06T21:32:49Z', 26, 'Contents API Checklist'}]"
# libzmq-win,"[{2, '2017-05-31T08:40:35Z', 'libraries 4.2.0-x64 miss TweetNacl'}]"
# commutable-perf,"[{'2016-11-09T18:47:28Z', 3, 'Create perf measuring scripts with commutable'}]"
# plotly.js,[]
# vega,[]
# commuter,"[{8, '2017-01-25T02:59:19Z', 'Support auth via aws_access_key_id & aws_secret_access_key '}, {9, '2017-01-25T03:04:00Z', 'Persist notebooks back to S3'}, {'Add tests for react components ', '2017-01-26T21:43:40Z', 13}, {'commuter  screen shots', 19, '2017-01-31T23:51:02Z'}]"
# snakestagram,"[{'Additional resources', 2, '2017-01-10T21:24:08Z'}, {'2017-01-10T21:32:50Z', 'Integrating with nteract build', 3}, {'Where to build?', 4, '2017-01-10T21:37:00Z'}, {'Where to store assets', 6, '2017-01-10T21:59:00Z'}]"
# commutable-models,[]
# minimal-plotly,"[{'2017-05-04T13:42:38Z', 4, 'Reduce size even further'}]"
# desktop-manual,"[{1, '2017-06-02T16:32:15Z', 'Add a link to the rendered book in README'}]"
# papermill,"[{'2017-07-06T20:47:53Z', 2, 'Dask (or threadpool) friendly functions'}, {'2017-07-10T22:57:59Z', 'execute module is missing', 4}, {'setup tox for testing locally', '2017-07-10T23:18:25Z', 7}, {'2017-08-09T11:16:39Z', 20, 'Is it possible to run with Jupyter Notebook (web env)?'}]"
# cabinet,[]
# papermillr,[]
# vdom,"[{'2017-09-19T21:01:01Z', 3, 'Write JSON Schema for the VDOM Spec'}, {'Create example notebooks', 4, '2017-09-19T21:03:07Z'}, {'2017-09-22T21:05:40Z', 'Check out JSON Markup Language', 7}, {'Write some best practices guidance for creating components', 11, '2017-09-25T18:45:41Z'}]"

# %% [markdown]
# ## Bring into pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('mydata.csv')

# %%
df.columns
# Out:
# Index(['name', 'issues'], dtype='object')

# %%
# df.head()

# %% [markdown]
# Generate basic report of total open issues

# %%
# df.dtypes

# %%
# df.index

# %%
# df.values

# %% [markdown]
# ### Reports

# %%
# By repo name
sorted_df = df.sort_values(by=['name'])
sorted_df
# Out:
#                            name  \
# 5                  batchspawner
# 24                       binder
# 22                    binderhub
# 1       configurable-http-proxy
# 3                 dockerspawner
# 21                   helm-chart
# 17                     hubshare
# 0                    jupyterhub
# 8      jupyterhub-deploy-docker
# 11        jupyterhub-deploy-hpc
# 9    jupyterhub-deploy-teaching
# 16  jupyterhub-example-kerberos
# 10          jupyterhub-tutorial
# 14               jupyterlab-hub
# 6                   kubespawner
# 7             ldapauthenticator
# 23          mybinder.org-deploy
# 18              nbrsessionproxy
# 15                nbserverproxy
# 25            nullauthenticator
# 2                oauthenticator
# 4                   sudospawner
# 12               systemdspawner
# 26                 team-compass
# 19             tmpauthenticator
# 13                  wrapspawner
# 20       zero-to-jupyterhub-k8s
#
#                                                issues
# 5   [{3, 'Implement testing', '2016-02-24T22:45:18...
# 24  [{'Discuss nomenclature', 3, '2017-08-18T17:57...
# 22  [{'Add a README', 1, '2017-05-06T21:19:55Z'}, ...
# 1   [{'Query by last activity API', 1, '2014-09-17...
# 3   [{2, '2014-09-27T21:08:00Z', 'Docker layout'},...
# 21  [{1, '2017-04-18T00:04:26Z', 'Allow customizin...
# 17  [{'2017-01-27T13:39:47Z', 'implement storage A...
# 0   [{2, 'use sqlalchemy ORM for state', '2014-08-...
# 8   [{'Problem with running/authenticating on an E...
# 11  [{'Add a jetstream instance for jupyterhub', 2...
# 9   [{'2016-04-19T05:17:09Z', 'Update cookie secre...
# 16  [{2, 'Detailed steps ?', '2017-04-25T11:30:58Z...
# 10  [{'Update and add links for jupyterhub-tutoria...
# 14  [{2, 'Unable to install the package', '2017-01...
# 6   [{1, 'Add a default health check for the pods'...
# 7   [{1, '2016-01-22T02:22:31Z', 'Support restrict...
# 23  [{'What is this repo for?', 2, '2017-09-19T15:...
# 18  [{'Are sessions secure?', 1, '2016-12-13T21:14...
# 15  [{1, 'Make it a standalone service', '2017-03-...
# 25                                                 []
# 2   [{8, '2015-07-25T02:07:48Z', 'GithubOAuthentic...
# 4   [{"SudoSpawner & 'No JSON object could be deco...
# 12  [{'2016-09-22T04:34:22Z', 1, 'Update url in se...
# 26  [{1, '2017-12-07T20:11:23Z', 'Use this repo fo...
# 19  [{'Update LICENSE', 3, '2017-08-26T16:01:45Z'}...
# 13  [{1, 'Migrate wrapspawner to this repo', '2016...
# 20  [{'Add initial build for RTD', 1, '2017-04-10T...

# %%
for x in sorted_df:
    name
    issues
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-e4a95010a8a9> in <module>()
#       1 for x in sorted_df:
#       2     name
# ----> 3     issues
#       4
#       5
#
# NameError: name 'issues' is not defined

# %%
# by open pr count
df.sort_values(by=['prs'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prs'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-53c6420b43b3> in <module>()
#       1 # by open pr count
# ----> 2 df.sort_values(by=['prs'], ascending=False)
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3617
#    3618             by = by[0]
# -> 3619             k = self.xs(by, axis=other_axis).values
#    3620             if k.ndim == 2:
#    3621
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3836
#    3837             if not isna(item):
# -> 3838                 loc = self.items.get_loc(item)
#    3839             else:
#    3840                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/pyquery/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prs'

# %%
# output data to a csv
# df.to_csv('issue_report.csv')
